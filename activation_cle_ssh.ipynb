# %% [markdown]
# Go to GitHub, navigate to **Personal Account** (not general settings) > Settings > SSH and GPG keys, and click New SSH key. Paste your key and save.
#
#
# Pour activer la clé SSH mise dans GitHub, exécuter DANS LE DÉPÔT CONCERNÉ, ici donc astronomers

# %%
git remote set-url origin git@github.com:Sciences-historiques-numeriques/astronomers.git

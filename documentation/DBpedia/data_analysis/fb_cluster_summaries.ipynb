# %%
import numpy as np
from sklearn.datasets import fetch_20newsgroups
import pandas as pd
from itables import init_notebook_mode, show
from collections import Counter
import networkx as nx
from pyvis.network import Network
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from collections import defaultdict
from sklearn import metrics
from time import time

# %% [markdown]
# ## Exercice personnel de clusterisation de textes
#
#
# * code issu de cet exemple: https://scikit-learn.org/stable/auto_examples/text/plot_document_clustering.html

# %% [markdown]
# ### Application à mes données —— commence ici

# %%
f = "book_titles.csv"
txt_astro = pd.read_csv(f, sep="|")

# %%
txt_astro.head()
# Out:
#    pk_idref_books  book_date                              simplified_title
# 0               1       2001  Structure interpretation classical mechanics
# 1               2       1926                     motion distribution stars
# 2               3       1968  Catalog emission lines astrophysical objects
# 3               4       1969  Catalog emission lines astrophysical objects
# 4               5       1976             Applied solar energy introduction

# %%
txt_astro.simplified_title[-10:-5]
# Out:
# 5521                    rôle Société Astronomique France
# 5522                                     أجمل تاريخ للكون
# 5523    Comment pensent savants leçons grands scientif...
# 5524                                   Hermann Carl Vogel
# 5525    L'Université l'usine (1956-1984) fondateur L...
# Name: simplified_title, dtype: object

# %% [markdown]
# ### Not in use

# %%
def ab(text):
    for ch in ['\\','\n','?','*','{','}','[',']','(',')','>','#',';',':','.','!','$','\'']:
        text = text.replace(ch,"")
    return text

# %%
print(ab('aéslfk? js#aélfk: jaésd$d,'))

# %%
def suppr_math(text):
    for ch in ['mathematics','mathematical','mathematician']:
        text = text.replace(ch,"")
    return text

# %%
txt_astro.head(2)

# %% [markdown]
# ### Follows from here the code

# %%
txt_astro['title'] = txt_astro['simplified_title'].apply(lambda x : x.lower().strip())

# %%
txt_astro.title[-10:-5]
# Out:
# 5521                    rôle société astronomique france
# 5522                                     أجمل تاريخ للكون
# 5523    comment pensent savants leçons grands scientif...
# 5524                                   hermann carl vogel
# 5525    l'université l'usine (1956-1984) fondateur l...
# Name: title, dtype: object

# %%
txt_astro['txt_len'] = txt_astro['title'].apply(lambda x : len(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_df=0.5,
    min_df=5,
    stop_words="english",
)

# %%
t0 = time()
X_tfidf = vectorizer.fit_transform(txt_astro.title)

print(f"vectorization done in {time() - t0:.3f} s")
print(f"n_samples: {X_tfidf.shape[0]}, n_features: {X_tfidf.shape[1]}")
# Out:
# vectorization done in 0.060 s
# n_samples: 5531, n_features: 1699

# %%
### https://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html
vectorizer.get_feature_names_out()[:5]

# %%
vectorizer.ngram_range

# %%
? X_tfidf

# %%
X_tfidf.data,X_tfidf.indices,X_tfidf.data

# %%
print(f"{X_tfidf.nnz / np.prod(X_tfidf.shape):.3f}")
# Out:
# 0.003

# %%
from sklearn.cluster import KMeans

for seed in range(5):
    kmeans = KMeans(
        n_clusters=20,
        max_iter=500,
        n_init=50,
        random_state=seed,
    ).fit(X_tfidf)
    cluster_ids, cluster_sizes = np.unique(kmeans.labels_, return_counts=True)
    print(f"Number of elements asigned to each cluster: {cluster_sizes}")
print()
# Out:
# Number of elements asigned to each cluster: [ 133   86   43   96  170   67   88  210   87   48  116  167  134   85
#    41  136  113  128 3504   79]
# Number of elements asigned to each cluster: [3516  183   90   64   81  103   66  161    8  233  117  126  141   30
#    88   38  240   54  131   61]
# Number of elements asigned to each cluster: [ 104 3631  169  160   53  116  225  125   55   45   52   91  133   89
#    84  202   73   20   75   29]
# Number of elements asigned to each cluster: [ 101  135  126   58  179   16  198   74 3634  126   60   53  102   85
#   126   72   66  178   90   52]
# Number of elements asigned to each cluster: [ 156  127  100   89  249   22   42   85 3536   55  133  243   91   75
#   171   38   23  112  101   83]

# %%
y_tfidf = kmeans.predict(X_tfidf)

# %%
y_tfidf[:10]

# %%
lines_classes =  ['_'+ str(i+1) if i < 9 else str(i+1) for i in y_tfidf]; lines_classes[:3]
# Out:
# ['_9', '_5', '_9']

# %%
len(lines_classes), len(txt_astro)

# %%
txt_astro.head()
# Out:
#    pk_idref_books  book_date                              simplified_title  \
# 0               1       2001  Structure interpretation classical mechanics
# 1               2       1926                     motion distribution stars
# 2               3       1968  Catalog emission lines astrophysical objects
# 3               4       1969  Catalog emission lines astrophysical objects
# 4               5       1976             Applied solar energy introduction
#
#                                           title class_search  class  txt_len
# 0  structure interpretation classical mechanics           _9      8       44
# 1                     motion distribution stars           _5      4       25
# 2  catalog emission lines astrophysical objects           _9      8       44
# 3  catalog emission lines astrophysical objects           _9      8       44
# 4             applied solar energy introduction           19     18       33

# %%
f = "book_titles_clusters.csv"
txt_astro.to_csv(f, sep='|')

# %%
txt_astro['class_search'] = lines_classes; txt_astro['class'] = y_tfidf

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(txt_astro.sort_values(by='txt_len'), classes="display", scrollY="500px", 
     scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")
# Out:
# <style>.itables table td {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables table th {
#     text-overflow: ellipsis;
#     overflow: hidden;
# }
#
# .itables thead input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
#
# .itables tfoot input {
#     width: 100%;
#     padding: 3px;
#     box-sizing: border-box;
# }
# </style>
# <div class="itables">
# <table id="89c8c795-a2a1-4054-934a-883f626de72b" class="display"style="table-layout:auto;width:auto;margin:auto;caption-side:bottom"><thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pk_idref_books</th>
#       <th>book_date</th>
#       <th>simplified_title</th>
#       <th>title</th>
#       <th>class_search</th>
#       <th>class</th>
#       <th>txt_len</th>
#     </tr>
#   </thead><tbody><tr><td>Loading... (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td></tr></tbody><tfoot><th>None</th><th>pk_idref_books</th><th>book_date</th><th>simplified_title</th><th>title</th><th>class_search</th><th>class</th><th>txt_len</th></tfoot></table>
# <link rel="stylesheet" type="text/css" href="https://cdn.datatables.net/1.13.1/css/jquery.dataTables.min.css">
# <script type="module">
#     // Import jquery and DataTable
#     import 'https://code.jquery.com/jquery-3.6.0.min.js';
#     import dt from 'https://cdn.datatables.net/1.12.1/js/jquery.dataTables.mjs';
#     dt($);
#
#     // Define the table data
#     const data = [[1642, 1645, 1882, "\u009csun", "\u009csun", "_9", 8, 4], [5500, 5504, 2021, "l'UR", "l'ur", "_9", 8, 4], [4338, 4342, 1978, "Mars", "mars", "_9", 8, 4], [871, 874, 1968, "\u009csun", "\u009csun", "_9", 8, 4], [2464, 2467, 1957, "\u009csun", "\u009csun", "_9", 8, 4], [588, 591, 1973, "Mars", "mars", "_9", 8, 4], [3107, 3110, 1870, "sole", "sole", "_9", 8, 4], [4166, 4170, 1895, "Mars", "mars", "_9", 8, 4], [3759, 3763, 1953, "\u009cmoon", "\u009cmoon", "_9", 8, 5], [3255, 3259, 1831, "Licht", "licht", "_9", 8, 5], [5164, 5168, 2005, "Terre", "terre", "17", 16, 5], [3753, 3757, 2010, "Monge", "monge", "_9", 8, 5], [4965, 4969, 1900, "\u009cLune", "\u009clune", "_9", 8, 5], [912, 915, 2002, "Venus", "venus", "_9", 8, 5], [5374, 5378, 2015, "terre", "terre", "17", 16, 5], [517, 520, 2022, "l'IBM", "l'ibm", "_9", 8, 5], [5321, 5325, 2003, "terre", "terre", "17", 16, 5], [1175, 1178, 1981, "\u009cmoon", "\u009cmoon", "_9", 8, 5], [209, 212, 1887, "Varia", "varia", "_9", 8, 5], [2318, 2321, 1935, "\u009cworld", "\u009cworld", "_9", 8, 6], [4936, 4940, 1957, "Optics", "optics", "_9", 8, 6], [5408, 5412, 1961, "\u009ccielo", "\u009ccielo", "_9", 8, 6], [5389, 5393, 2015, "Galets", "galets", "_9", 8, 6], [718, 721, 1982, "Saturn", "saturn", "_9", 8, 6], [5309, 5313, 1990, "Soleil", "soleil", "_9", 8, 6], [5183, 5187, 1977, "Soleil", "soleil", "_9", 8, 6], [2011, 2014, 2006, "\u009cworld", "\u009cworld", "_9", 8, 6], [454, 457, 1981, "Cosmos", "cosmos", "_9", 8, 6], [5332, 5336, 1980, "Soleil", "soleil", "_9", 8, 6], [44, 45, 1985, "Com\u00e8te", "com\u00e8te", "_9", 8, 6], [2204, 2207, 1949, "\u009cworld", "\u009cworld", "_9", 8, 6], [5263, 5267, 2006, "limite", "limite", "_9", 8, 6], [1295, 1298, 1883, "\u009cSonne", "\u009csonne", "_9", 8, 6], [368, 371, 1995, "Cosmos", "cosmos", "_9", 8, 6], [390, 393, 1981, "Cosmos", "cosmos", "_9", 8, 6], [2423, 2426, 1979, "\u009cworld", "\u009cworld", "_9", 8, 6], [4511, 4515, 2024, "Amp\u00e8re", "amp\u00e8re", "_9", 8, 6], [892, 895, 1935, "\u5f9e\u539f\u5b50\u5230\u9280\u6cb3", "\u5f9e\u539f\u5b50\u5230\u9280\u6cb3", "_9", 8, 6], [3893, 3897, 1957, "\u009cMilky", "\u009cmilky", "_9", 8, 6], [4074, 4078, 1974, "\u009cMilky", "\u009cmilky", "_9", 8, 6], [4864, 4868, 1977, "\u009ccielo", "\u009ccielo", "_9", 8, 6], [114, 117, 1981, "Cosmos", "cosmos", "_9", 8, 6], [3989, 3993, 1981, "\u009cMilky", "\u009cmilky", "_9", 8, 6], [222, 225, 1882, "comets", "comets", "_9", 8, 6], [2569, 2572, 1929, "Planet", "planet", "_9", 8, 6], [3407, 3411, 1857, "Oeuvres", "oeuvres", "18", 17, 7], [336, 339, 1986, "Contact", "contact", "_9", 8, 7], [3421, 3425, 1962, "Gravity", "gravity", "_9", 8, 7], [5342, 5346, 2000, "V\u0101irasa", "v\u0101irasa", "_9", 8, 7], [3259, 3263, 1962, "Gravity", "gravity", "_9", 8, 7], [63, 64, 1999, "Contact", "contact", "_9", 8, 7], [740, 743, 1981, "Jupiter", "jupiter", "_9", 8, 7], [391, 394, 2011, "Contact", "contact", "_9", 8, 7], [823, 826, 1991, "l'homme", "l'homme", "_9", 8, 7], [2251, 2254, 1908, "Janssen", "janssen", "_9", 8, 7], [5528, 5532, 1986, "\u0927\u0942\u092e\u0915\u0947\u0924\u0941", "\u0927\u0942\u092e\u0915\u0947\u0924\u0941", "_9", 8, 7], [4564, 4568, 1990, "\u009cfuture", "\u009cfuture", "_9", 8, 7], [427, 430, 1986, "Contact", "contact", "_9", 8, 7], [8, 9, 1971, "Planets", "planets", "_9", 8, 7], [1297, 1300, 1883, "\u009csoleil", "\u009csoleil", "_9", 8, 7], [7, 8, 1970, "plan\u00e8tes", "plan\u00e8tes", "_9", 8, 8], [942, 945, 1972, "Galaxies", "galaxies", "_9", 8, 8], [1083, 1086, 1961, "Galaxies", "galaxies", "_9", 8, 8], [821, 824, 1947, "Galaxies", "galaxies", "_9", 8, 8], [4102, 4106, 1985, "\u009cplanets", "\u009cplanets", "_9", 8, 8], [3282, 3286, 1992, "Tompkins", "tompkins", "_9", 8, 8], [1451, 1454, 1997, "\u009cchaleur", "\u009cchaleur", "_9", 8, 8], [3111, 3114, 1966, "galaxies", "galaxies", "_9", 8, 8], [2686, 2689, 1964, "galaxies", "galaxies", "_9", 8, 8], [5383, 5387, 1908, "Discours", "discours", "_9", 8, 8], [3122, 312 ...

# %%
txt_astro['tokens'] = txt_astro['summ_repl'].apply(lambda x : x.split(' '))

# %%
dfg = pd.DataFrame(txt_astro.groupby('class')['tokens'].apply(list))
dfg.columns = ['tokens']
dfg = dfg.reset_index()
dfg.head(2)

# %%
def most_frequent_tokens(l):
    sl = sum(l, [])
    kl = [tk.replace('\n', '') \
          #.replace('.', '').replace(',', '').strip().lower() \
          for tk in sl if len(tk)>3]
          #for tk in sl if len(tk)>3 and tk not in ('mathematician','worked', 'work', 'known')]
    skl = pd.Series(Counter(kl))
    fskl = skl.loc[lambda x : x > 3].sort_values(ascending=False)
    final_l = fskl.iloc[:20].to_dict()
    
    return final_l

# %%
dfg['mf_tokens'] = dfg['tokens'].apply(lambda x : most_frequent_tokens(x))

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(dfg, classes="display", scrollY="400px", 
     scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")

# %% [markdown]
# ### Produce graph

# %%
fl = dfg['mf_tokens'][0]; fl

# %%
l = dfg['tokens'][1][0]; l[:7]

# %%
[i for i in l if i in fl.keys()]

# %%
sorted(['William', 'Morgan', 'was', 'an', 'early', 'actuary'])

# %%
l =  ['Morgan', 'William', 'actuary', 'an', 'early', 'was']

# %%
def tks_graph(l, fl):
    lfk = list(fl.keys())

    le_dct= []
    for e in l: 
        l_dct= []
        sl = sorted([i for i in e if len(i) > 3 and i in lfk ])
        for i in sl:
            for v in sl:
                if i < v:
                    l_dct.append([i,v])
        #print(l_dct)
        le_dct += l_dct            
    return le_dct

# %%
dfg['tokens_graph'] = dfg.apply(lambda x : tks_graph(x.tokens,x.mf_tokens), axis=1)
dfg.head()

# %%
dfg.tokens_graph[:3]

# %%
ll = [tuple(e) for e in dfg.loc[0]['tokens_graph']]; # ll

# %%
fl = dfg['mf_tokens'][0]; fl

# %%
d_eff = dict([(k, {'eff':v}) for k,v in fl.items()]); d_eff

# %%
G = nx.Graph()
G.add_edges_from(ll)

# %%
G.nodes()

# %%
nx.set_node_attributes(G, d_eff)

# inspecter les sommets et leurs attributs
list(G.nodes.data())

# %%
nx.get_node_attributes(G, 'eff').values()

# %%
[i]

# %%
pos = nx.kamada_kawai_layout(G)
fig = plt.figure(figsize = (12,9))
fig.tight_layout()
# nx.draw_networkx(G, pos, node_size=10)
nx.draw_networkx_edges(G, pos, alpha=0.1)
nx.draw_networkx_labels(G, pos, horizontalalignment='left', verticalalignment='bottom')
nx.draw_networkx_nodes(G, pos, node_size= list(nx.get_node_attributes(G, 'eff').values()))

# %%
# https://engineeringfordatascience.com/posts/matplotlib_subplots/
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplot.html#sphx-glr-gallery-subplots-axes-and-figures-subplot-py


plt.subplots_adjust( hspace=10)
ncols = 1
# calculate number of rows
nrows = len(dfg) 

i = 0






while i < nrows :

    val = pd.DataFrame.from_dict(dfg.iloc[i]['mf_tokens'], orient='index')
    val.columns=['eff']
    val['y_val'] = [1]*len(val)
    # val['ln_eff'] = val['eff'].apply(lambda x : np.log(x)) ça n'apporte rien


    # print(val.eff)
    
    # ax= plt.subplot(nrows,1,i+1)
    
    ax = plt.figure(figsize=(14,3))



    ax = sns.scatterplot(val, x = 'eff', y = 'y_val', alpha = 0.5)
    
    # plt.xlabel(val['eff'].to_dict(), fontsize=14, wrap=True)
    
    ax.collections[0].set_sizes(val.eff**2) 

    ax.set_xlim(min(val.eff)- min(val.eff)/10, max(val.eff)+max(val.eff)/20)
    ax.set_ylim(0, 2)
    ax.invert_xaxis()

    #For each point, we add a text inside the bubble
    for line in range(0,val.shape[0]):
         ax.text(val.eff[line], val.y_val[line]+ 0.2, str(val.index[line]).replace('{}', ''),
                 rotation=45,horizontalalignment='center', 
                 size=10, color='black') # , weight='semibold'

    ax.set_title(f'Cluster {i}', fontsize=18)

    plt.tight_layout()   

    plt.show()
    
    
    
    ### 
    ll = [tuple(e) for e in dfg.iloc[i]['tokens_graph']]
    fl = dfg['mf_tokens'][i]
    d_eff = dict([(k, {'eff':v}) for k,v in fl.items()])
    G = nx.Graph()
    G.add_edges_from(ll)
    nx.set_node_attributes(G, d_eff)
    
    d = sorted(nx.get_node_attributes(G, 'eff').items(), key=lambda x: x[1], reverse=True)
    print(d)
    
    pos = nx.kamada_kawai_layout(G)
    fig = plt.figure(figsize = (6,4))
    fig.tight_layout()
    # nx.draw_networkx(G, pos, node_size=10)
    nx.draw_networkx_edges(G, pos, alpha=0.1)
    nx.draw_networkx_labels(G, pos, horizontalalignment='left', verticalalignment='bottom')
    nx.draw_networkx_nodes(G, pos, node_size= list(nx.get_node_attributes(G, 'eff').values()))


    ax.set_title(f'Cluster {i}', fontsize=18)

    plt.tight_layout()   
    i = i + 1
    plt.show()

# %% [markdown]
# ### Les 20 mots les plus fréquents par classe

# %%
# https://engineeringfordatascience.com/posts/matplotlib_subplots/
# https://matplotlib.org/stable/gallery/subplots_axes_and_figures/subplot.html#sphx-glr-gallery-subplots-axes-and-figures-subplot-py


plt.subplots_adjust( hspace=10)
ncols = 1
# calculate number of rows
nrows = len(dfg) 

i = 0






while i < nrows :

    ### 
    val = pd.DataFrame.from_dict(dfg.iloc[i]['mf_tokens'], orient='index')
    val.columns=['eff']
    val['y_val'] = [1]*len(val)
    # val['ln_eff'] = val['eff'].apply(lambda x : np.log(x)) ça n'apporte rien


    # print(val.eff)
    
    # ax= plt.subplot(nrows,1,i+1)
    
    ax = plt.figure(figsize=(30,6))



    ax = sns.scatterplot(val, x = 'eff', y = 'y_val', alpha = 0.5)
    
    plt.xlabel(val['eff'].to_dict(), fontsize=14, wrap=True)
    
    ax.collections[0].set_sizes(val.eff**2) 

    ax.set_xlim(min(val.eff)- min(val.eff)/10, max(val.eff)+max(val.eff)/20)
    ax.set_ylim(0, 2)
    ax.invert_xaxis()

    #For each point, we add a text inside the bubble
    for line in range(0,val.shape[0]):
         ax.text(val.eff[line], val.y_val[line]+ 0.2, str(val.index[line]).replace('{}', ''),
                 rotation=45,horizontalalignment='center', 
                 size=16, color='black') # , weight='semibold'

    ax.set_title(f'Cluster {i}', fontsize=18)

    plt.tight_layout()   
    i = i + 1
    plt.show()

# %% [markdown]
# ## Préparation

# %%
val = pd.DataFrame.from_dict((dfg.iloc[7].values)[0], orient='index'); type(val)
val.columns=['eff']
val['y_val'] = [1]*len(val)
# val['ln_eff'] = val['eff'].apply(lambda x : np.log(x)) ça n'apporte rien

# %%
fig = plt.figure(figsize=(20, 4))


val = pd.DataFrame.from_dict((dfg.iloc[0].values)[0], orient='index'); type(val)
val.columns=['eff']
val['y_val'] = [1]*len(val)
# val['ln_eff'] = val['eff'].apply(lambda x : np.log(x)) ça n'apporte rien


ax = sns.scatterplot(val, x = 'eff', y = 'y_val', alpha = 0.5)
ax.set(xlabel=val['eff'].to_dict())
ax.collections[0].set_sizes(val.eff**2) 

ax.set_xlim(min(val.eff)- min(val.eff)/10, max(val.eff)+max(val.eff)/20)
ax.set_ylim(0, 2)
ax.invert_xaxis()

#For each point, we add a text inside the bubble
for line in range(0,val.shape[0]):
     ax.text(val.eff[line], val.y_val[line]+ 0.2, str(val.index[line]).replace('{}', ''),
             rotation=45,horizontalalignment='center', 
             size=12, color='black') # , weight='semibold'

# %%
dfg = pd.DataFrame(txt_astro.groupby('class')['tokens'].apply(list))
dfg.columns = ['tokens']

# %%
# dfg.head(8), type(dfg)

# %%
dfg['tokens'] = dfg['tokens'].apply(lambda x : most_frequent_tokens(x))

# %%
### https://github.com/mwouts/itables/blob/main/docs/advanced_parameters.md
show(dfg, classes="display", scrollY="400px", 
     scrollCollapse=True, paging=False, column_filters="footer", dom="lrtip")

# %%
l_dct= []
for i in dct:
    for v in dct:
        if i < v:
            l_dct.append([i,v])
l_dct[:5]

# %%
G = nx.Graph()
G.add_edges_from(l_dct)

# %%
pos = nx.spring_layout(G)
fig = plt.figure(figsize = (30,20))
fig.tight_layout()
nx.draw_networkx(G, pos, node_size=10)

# %%
### 
# https://pyvis.readthedocs.io/en/latest/tutorial.html#using-pyvis-within-jupyter-notebook
nt = Network( notebook=True) #, filter_menu=True)
# populates the nodes and edges data structures
nt.from_nx(G)
nt.show('pictures/nx.html' )

# %%
def prepare_graph(val):
    dct = {val}

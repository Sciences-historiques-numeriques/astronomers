# %%
### Librairie à installer dans l'environnement conda (si on exécute en local)
# qui sera choisi pour exécuter le carnet
from SPARQLWrapper import SPARQLWrapper, JSON, TURTLE, XML, RDFXML, POST

import pandas as pd

import matplotlib.pyplot as plt
import numpy as np

import sys
from importlib import reload
import os

# %%
### Importer un module de fonctions crées ad hoc
##  ATTENTION : le fichier 'sparql_functions.py' doit se trouver 
#   dans un dossier qui se situe dans le chemin ('path') de recherche
#   vu par le présent carnet Jupyter afin que
#   l'importation fonctionne correctement

# Add parent directory to the path
sys.path.insert(0, '..')

### If you want to add the parent-parent directory,
sys.path.insert(0, '../..')


import sparql_functions as spqf

# %% [markdown]
# ## SPARQL Query qui récupère les données
#
# On exécute la requête grâce à une fonction de la librairie locale qui réalise la mise en forme

# %%
## define SPARQL enpoint
endpoint = "https://ag16gm9pr0meths2.allegrograph.cloud/repositories/astronomers"

# %%
u = os.environ.get('ALG_WRITE_US')
p = os.environ.get('ALG_WRITE_PS')

# %%
query = """
### Resources authors and, optionally, editors


PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
PREFIX owl: <http://www.w3.org/2002/07/owl#>
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX dcterms:	<http://purl.org/dc/terms/>
PREFIX marcrel:	<http://id.loc.gov/vocabulary/relators/>
PREFIX dc11:	<http://purl.org/dc/elements/1.1/>

WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
INSERT {
  # ?s marcrel:aut ?author.
  # ?s marcrel:edt ?editor.
 }
WHERE {  
  {
    SELECT DISTINCT ?s
  WHERE {
    {?s marcrel:aut ?idRef}
    } 
    # OFFSET 100
    LIMIT 4000
  }
  SERVICE <https://data.idref.fr/sparql> {
         # ?s marcrel:aut ?author.   
         OPTIONAL {?s marcrel:edt ?editor}
  }
}
"""

# %%
sparql = SPARQLWrapper(endpoint)
sparql.setCredentials(u, p)
sparql.setMethod(POST)

sparql.setQuery(query) 

results = sparql.query()
print(results.response.read())
# Out:
# b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'

# %%
i = 0

# number of works
while i < 90000: 

    query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX dcterms:	<http://purl.org/dc/terms/>
    PREFIX marcrel: <http://id.loc.gov/vocabulary/relators/>
    PREFIX dc11:	<http://purl.org/dc/elements/1.1/>

    WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
    INSERT {
    # ?s marcrel:aut ?author.
    # ?s marcrel:edt ?editor.
    }
    WHERE {  
    {
        SELECT DISTINCT ?s
    WHERE {
        {?s marcrel:aut ?idRef}
        } 
        OFFSET """ + str(i) + """
        LIMIT 4000
    }
    SERVICE <https://data.idref.fr/sparql> {
            # ?s marcrel:aut ?author.   
            OPTIONAL {?s marcrel:edt ?editor}
    }
    }
    """

    sparql.setQuery(query) 

    try:
        results = sparql.query()
        print(i, results.response.read())
    except Exception as e:
        print(e)    
    i += 4000

# %% [markdown]
# ## Add dates, types to documents
#
#
# The basic type is document

# %%
### Add date


i = 0

# number of works
while i < 90000: 

    query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX dcterms:	<http://purl.org/dc/terms/>
    PREFIX marcrel: <http://id.loc.gov/vocabulary/relators/>
    PREFIX dc11:	<http://purl.org/dc/elements/1.1/>

    WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
    INSERT {
    # ?s dc11:date ?date.
    }
    WHERE {  
    {
        SELECT DISTINCT ?s
    WHERE {
        {?s marcrel:aut ?idRef}
        } 
        OFFSET """ + str(i) + """
        LIMIT 4000
    }
    SERVICE <https://data.idref.fr/sparql> {
            # ?s dc11:date ?date.   
    }
    }
    """

    sparql.setQuery(query) 

    try:
        results = sparql.query()
        print(i, results.response.read())
    except Exception as e:
        print(e)    
    i += 4000

# %%
### Add type


i = 0

# number of works
while i < 90000: 

    query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX dcterms:	<http://purl.org/dc/terms/>
    PREFIX marcrel: <http://id.loc.gov/vocabulary/relators/>
    PREFIX dc11:	<http://purl.org/dc/elements/1.1/>
    PREFIX bibo: <http://purl.org/ontology/bibo/>

    WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
    INSERT {
    # ?s rdf:type ?type.
    }
    WHERE {  
    {
        SELECT DISTINCT ?s
    WHERE {
        {?s marcrel:aut ?idRef}
        } 
        OFFSET """ + str(i) + """
        LIMIT 4000
    }
    SERVICE <https://data.idref.fr/sparql> {
            # ?s rdf:type ?type. 
           
    }
    }
    """

    sparql.setQuery(query) 

    try:
        results = sparql.query()
        print(i, results.response.read())
        i += 4000
    except Exception as e:
        print(e)

# %%
### Add dcterms:subject


i = 0

# number of works
while i < 90000: 

    query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX dcterms:	<http://purl.org/dc/terms/>
    PREFIX marcrel: <http://id.loc.gov/vocabulary/relators/>
    PREFIX dc11:	<http://purl.org/dc/elements/1.1/>
    PREFIX bibo: <http://purl.org/ontology/bibo/>

    WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
    INSERT {
    # ?s dcterms:subject ?subject.
    }
    WHERE {  
    {
        SELECT DISTINCT ?s
    WHERE {
        {?s marcrel:aut ?idRef}
        } 
        OFFSET """ + str(i) + """
        LIMIT 4000
    }
    SERVICE <https://data.idref.fr/sparql> {
            # ?s dcterms:subject ?subject. 
           
    }
    }
    """

    sparql.setQuery(query) 

    try:
        results = sparql.query()
        print(i, results.response.read())
        i += 4000
    except Exception as e:
        print(e)

# %%
### Add dc11:subject
# The books do not seem to have this kind of types


i = 0

# number of works
while i < 90000: 

    query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX dcterms:	<http://purl.org/dc/terms/>
    PREFIX marcrel: <http://id.loc.gov/vocabulary/relators/>
    PREFIX dc11:	<http://purl.org/dc/elements/1.1/>
    PREFIX bibo: <http://purl.org/ontology/bibo/>

    WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
    INSERT {
    # ?s dc11:subject ?subject.
    }
    WHERE {  
    {
        SELECT DISTINCT ?s
    WHERE {
        {?s marcrel:aut ?idRef}
        } 
        OFFSET """ + str(i) + """
        LIMIT 4000
    }
    SERVICE <https://data.idref.fr/sparql> {
            # ?s dc11:subject ?subject. 
           
    }
    }
    """

    sparql.setQuery(query) 

    try:
        results = sparql.query()
        print(i, results.response.read())
        i += 4000
    except Exception as e:
        print(e)

# %%
### Add dcterms:bibliographicCitation
# The books do not seem to have this kind of types


i = 0

# number of works
while i < 90000: 

    query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX dcterms:	<http://purl.org/dc/terms/>
    PREFIX marcrel: <http://id.loc.gov/vocabulary/relators/>
    PREFIX dc11:	<http://purl.org/dc/elements/1.1/>
    PREFIX bibo: <http://purl.org/ontology/bibo/>

    WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
    INSERT {
    # ?s dcterms:bibliographicCitation ?refBiblio.
    }
    WHERE {  
    {
        SELECT DISTINCT ?s
    WHERE {
        {?s marcrel:aut ?idRef}
        } 
        OFFSET """ + str(i) + """
        LIMIT 4000
    }
    SERVICE <https://data.idref.fr/sparql> {
            # ?s dcterms:bibliographicCitation ?refBiblio. 
           
    }
    }
    """

    sparql.setQuery(query) 

    try:
        results = sparql.query()
        print(i, results.response.read())
        i += 4000
    except Exception as e:
        print(e)

# %% [markdown]
# ## Add information about persons

# %%
### Add names to persons


i = 0

# number of persons
while i < 32000: 

    query = """
    PREFIX wdt: <http://www.wikidata.org/prop/direct/>
    PREFIX rdf:	<http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX owl: <http://www.w3.org/2002/07/owl#>
    PREFIX wd: <http://www.wikidata.org/entity/>
    PREFIX dcterms:	<http://purl.org/dc/terms/>
    PREFIX marcrel: <http://id.loc.gov/vocabulary/relators/>
    PREFIX dc11:	<http://purl.org/dc/elements/1.1/>
    PREFIX bibo: <http://purl.org/ontology/bibo/>
    PREFIX skos: <http://www.w3.org/2004/02/skos/core#>

    WITH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/idref.md>
    INSERT {
    # ?s skos:prefLabel ?prefLabel.
    }
    WHERE {  
    {
        SELECT DISTINCT ?s
    WHERE {
        {?s rdf:type foaf:Person}
        } 
        OFFSET """ + str(i) + """
        LIMIT 4000
    }
    SERVICE <https://data.idref.fr/sparql> {
            # ?s skos:prefLabel ?prefLabel. 
           
    }
    }
    """

    sparql.setQuery(query) 

    try:
        results = sparql.query()
        print(i, results.response.read())
        i += 4000
    except Exception as e:
        print(e)
# Out:
# 0 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'
# 4000 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'
# 8000 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'
# 12000 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'
# 16000 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'
# 20000 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'
# 24000 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'
# 28000 b'<?xml version="1.1"?>\n<!-- Generated by AllegroGraph 8.3.1 -->\n<sparql xmlns="http://www.w3.org/2005/sparql-results#">\n  <head/>\n  <boolean>true</boolean>\n</sparql>'

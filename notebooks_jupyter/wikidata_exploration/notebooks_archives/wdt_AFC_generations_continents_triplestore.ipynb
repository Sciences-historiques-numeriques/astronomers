# %% [markdown]
# # Analyse factorielle des correspondances: génération, genre, continent, champ scientifique principal
#
# Pour l'importation des données, voir ces carnets sparqlbook:
# * [Occupations](../../sparqlbooks/wdt_import_occupations.sparqlbook.md)
# * [Field](../../sparqlbooks/wdt_import_fields.sparqlbook.md)
# * [Continents](../../sparqlbooks/wdt_import_citizenships.sparqlbook.md)
#
#
# Pour vérifier l'ensemble des informations disponibles, voir ce carnet sparqlbook:
# * [Information disponible](../../sparqlbooks/wdt_available_information.sparqlbook.md )

# %%
### Librairie à installer dans l'environnement conda (si on exécute en local)
# qui sera choisi pour exécuter le carnet
from SPARQLWrapper import SPARQLWrapper, JSON, TURTLE, XML, RDFXML
import pandas as pd
import numpy as np
import scipy.stats as stats

from fanalysis.ca import CA 

import matplotlib.pyplot as plt
import seaborn as sns

### Module de visualisation de données
#  https://mwouts.github.io/itables/quick_start.html

from itables import init_notebook_mode, show

init_notebook_mode(all_interactive=False)
# Out:
# <script>
#     if (document.body.dataset.jpThemeLight == "false" || // Jupyter Lab
#         document.body.dataset.vscodeThemeKind == "vscode-dark" || // VS Code
#         document.documentElement.dataset.theme == "dark" || // Jupyter Book
#         window.matchMedia('(prefers-color-scheme: dark)').matches) {
#         document.documentElement.classList.add('dark');
#     }
#     else {
#         document.documentElement.classList.remove('dark');
#     }
# </script>
# <style>:root{--dt-row-selected: 13, 110, 253;--dt-row-selected-text: 255, 255, 255;--dt-row-selected-link: 9, 10, 11;--dt-row-stripe: 0, 0, 0;--dt-row-hover: 0, 0, 0;--dt-column-ordering: 0, 0, 0;--dt-html-background: white}:root.dark{--dt-html-background: rgb(33, 37, 41)}table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{display:inline-block;box-sizing:border-box;content:"";border-top:5px solid transparent;border-left:10px solid rgba(0,0,0,.5);border-bottom:5px solid transparent;border-right:0px solid transparent}table.dataTable tr.dt-hasChild td.dt-control:before{border-top:10px solid rgba(0,0,0,.5);border-left:5px solid transparent;border-bottom:0px solid transparent;border-right:5px solid transparent}html.dark table.dataTable td.dt-control:before,:root[data-bs-theme=dark] table.dataTable td.dt-control:before{border-left-color:#ffffff80}html.dark table.dataTable tr.dt-hasChild td.dt-control:before,:root[data-bs-theme=dark] table.dataTable tr.dt-hasChild td.dt-control:before{border-top-color:#ffffff80;border-left-color:transparent}div.dt-scroll-body thead tr,div.dt-scroll-body tfoot tr{height:0}div.dt-scroll-body thead tr th,div.dt-scroll-body thead tr td,div.dt-scroll-body tfoot tr th,div.dt-scroll-body tfoot tr td{height:0!important;padding-top:0!important;padding-bottom:0!important;border-top-width:0px!important;border-bottom-width:0px!important}div.dt-scroll-body thead tr th div.dt-scroll-sizing,div.dt-scroll-body thead tr td div.dt-scroll-sizing,div.dt-scroll-body tfoot tr th div.dt-scroll-sizing,div.dt-scroll-body tfoot tr td div.dt-scroll-sizing{height:0!important;overflow:hidden!important}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order:before{position:absolute;display:block;bottom:50%;content:"\25b2";content:"\25b2"/""}table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order:after{position:absolute;display:block;top:50%;content:"\25bc";content:"\25bc"/""}table.dataTable thead>tr>th.dt-orderable-asc,table.dataTable thead>tr>th.dt-orderable-desc,table.dataTable thead>tr>th.dt-ordering-asc,table.dataTable thead>tr>th.dt-ordering-desc,table.dataTable thead>tr>td.dt-orderable-asc,table.dataTable thead>tr>td.dt-orderable-desc,table.dataTable thead>tr>td.dt-ordering-asc,table.dataTable thead>tr>td.dt-ordering-desc{position:relative;padding-right:30px}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-asc span.dt-column-order,table.dataTable thead>tr>td.dt-orderable-desc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-asc span.dt-column-order,table.dataTable thead>tr>td.dt-ordering-desc span.dt-column-order{position:absolute;right:12px;top:0;bottom:0;width:12px}table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-asc span.dt-column-order:after,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:before,table.dataTable thead>tr>th.dt-orderable-desc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-asc span.dt-column-order:after,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:before,table.dataTable thead>tr>th.dt-ordering-desc span.dt-column-order:after,table.dataTable thead>tr>td.dt-o ...

# %%
### Librairies déjà installées avec Python
import pprint
import csv
import sys

import sqlite3 as sql

import time
import datetime
from dateutil import parser

from importlib import reload
from shutil import copyfile

# %%
### Importer un module de fonctions crées ad hoc
##  ATTENTION : le fichier 'sparql_functions.py' doit se trouver 
#   dans un dossier qui se situe dans le chemin ('path') de recherche
#   vu par le présent carnet Jupyter afin que
#   l'importation fonctionne correctement

# Add parent directory to the path
sys.path.insert(0, '..')

### If you want to add the parent-parent directory,
sys.path.insert(0, '../..')


import sparql_functions as spqf

# %% [markdown]
# ## SPARQL Query qui récupère les données
#
# On exécute la requête grâce à une fonction de la librairie locale qui réalise la mise en forme

# %%
## define SPARQL enpoint
endpoint = "https://ag16gm9pr0meths2.allegrograph.cloud/repositories/astronomers"

# %%
query = """
PREFIX wd: <http://www.wikidata.org/entity/>
PREFIX wdt: <http://www.wikidata.org/prop/direct/>
PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>


SELECT  ?s (MAX(?label) as ?label) (xsd:integer(MAX(?birthDate)) as ?birthDate) 
            ( GROUP_CONCAT(DISTINCT ?genderLabel; separator=", ") AS ?genders ) 
            ( GROUP_CONCAT(DISTINCT ?countryLabel; separator=", ") AS ?countries )
            ( GROUP_CONCAT(DISTINCT ?continentLabel; separator=", ") AS ?continents )
            ( GROUP_CONCAT(DISTINCT ?occupationLabel; separator=", ") AS ?occupations )
            ( GROUP_CONCAT(DISTINCT ?fieldLabel; separator=", ") AS ?fields )
WHERE {
    GRAPH <https://github.com/Sciences-historiques-numeriques/astronomers/blob/main/graphs/wikidata-imported-data.md>
        {?s wdt:P21 ?gender;
            rdfs:label ?label;
            wdt:P569 ?birthDate;
            wdt:P27 ?country.
        # ?gender rdfs:label ?genderLabel.
        OPTIONAL {
        # ?country rdfs:label ?countryLabel.
        # ?country wdt:P30 ?continent.
        # ?continent rdfs:label ?continentLabel.
        FILTER ( ?continent NOT IN ( wd:Q3960, wd:Q538))}
        OPTIONAL {  ?s wdt:P106 ?occupation.
                    # ?occupation rdfs:label ?occupationLabel.}
        OPTIONAL {  ?s wdt:P101 ?field.
                    # ?field rdfs:label ?fieldLabel.}

        ## Excluding Australia and Oceania insular
        # Eurasia : wd:Q5401 
        
          }
}
GROUP BY ?s
"""

# %%
### Executer la requête avec les fonctions de la librairie locale
qr = spqf.get_json_sparql_result(endpoint,query)

# %%
r = [l for l in spqf.sparql_result_to_list(qr)]
print(len(r))
r[:3]
# Out:
# 23692
# [['http://www.wikidata.org/entity/Q97193482',
#   'Q97193482',
#   '1941',
#   'male',
#   'Soviet Union, Ukraine',
#   'Asia, Europe',
#   'physicist',
#   ''],
#  ['http://www.wikidata.org/entity/Q4511380',
#   'Anita Goel',
#   '1973',
#   'female',
#   'India, United States',
#   'Asia, North America',
#   'physicist, biophysicist',
#   ''],
#  ['http://www.wikidata.org/entity/Q4706857',
#   'Alan Herries Wilson',
#   '1906',
#   'male',
#   'United Kingdom',
#   'Europe',
#   'physicist, mathematician',
#   '']]

# %%
### Créer un DataFrame à partir du résultat
df_p = pd.DataFrame(r)
df_p.columns = ['personUri', 'personLabel', 'birthYear', 'gender', 'countries', 'continents', 'occupations', 'fields']
df_p.head()
# Out:
#                                   personUri          personLabel birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482      1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel      1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson      1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber      1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda      1931
#
#    gender                      countries           continents  \
# 0    male          Soviet Union, Ukraine         Asia, Europe
# 1  female           India, United States  Asia, North America
# 2    male                 United Kingdom               Europe
# 3    male  Israel, United States, Canada  Asia, North America
# 4    male                 Czechoslovakia               Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             physicist, academic
# 4  physicist, chemist, pharmacist
#
#                                            fields
# 0
# 1
# 2
# 3  nuclear physics, cosmology, general relativity
# 4

# %%
## transformer les années en entiers
df_p.birthYear = df_p.birthYear.apply(lambda x : int(x))

# %%
### Verify if there's just one row per person
cf_pc = pd.DataFrame(df_p.groupby('personUri').size())
# cf_pc.reset_index(inplace=True)
cf_pc.columns = ['number']
cf_pc.sort_values('number', ascending=False).head(3)
# Out:
#                                          number
# personUri
# http://www.wikidata.org/entity/Q999927        1
# http://www.wikidata.org/entity/Q1000193       1
# http://www.wikidata.org/entity/Q1000934       1

# %%
### Store to CSV if you want to avoid repeating the query:
# you can then juste reload the data
f_path = 'data/df_continent_occupations_fields_20250413.csv'

# %%
### Store
df_p.to_csv(f_path)

# %%
### Read
# df_p = pd.read_csv(f_path, index_col=0)

# %%
df_p.head(3)
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
#
#    gender              countries           continents  \
# 0    male  Soviet Union, Ukraine         Asia, Europe
# 1  female   India, United States  Asia, North America
# 2    male         United Kingdom               Europe
#
#                 occupations fields
# 0                 physicist
# 1   physicist, biophysicist
# 2  physicist, mathematician

# %%
### Inspecter la structure du dataframe
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23692 entries, 0 to 23691
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   personUri    23692 non-null  object
#  1   personLabel  23692 non-null  object
#  2   birthYear    23692 non-null  int64
#  3   gender       23692 non-null  object
#  4   countries    23692 non-null  object
#  5   continents   23692 non-null  object
#  6   occupations  23692 non-null  object
#  7   fields       23692 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 1.4+ MB

# %% [markdown]
# ## Coder les continents et afficher leur distribution

# %%
### Inspecter les données
print(df_p.iloc[ :5 , :].continents)
# Out:
# 0           Asia, Europe
# 1    Asia, North America
# 2                 Europe
# 3    Asia, North America
# 4                 Europe
# Name: continents, dtype: object

# %%
df_p.continents = df_p.continents.apply(lambda x : str(x))

# %%
def split_strip_sort (x):
    a = x.split(',')
    b = sorted([e.strip() for e in a])
    c = ','.join(b)
    return c

# %%
print(split_strip_sort('Asia, North America, Eurasia'))
# Out:
# Asia,Eurasia,North America

# %%
print(split_strip_sort('Asia'))
# Out:
# Asia

# %%
print(df_p.groupby(by='continents').size().sort_values(ascending=False))
# Out:
# continents
# Europe                                  13343
# North America                            4248
# Asia                                     2055
# Asia, Europe                             1828
# Asia, Eurasia, North America, Europe      416
# North America, Europe                     394
# South America                             389
# Oceania                                   288
# Eurasia, North America                    192
# Africa                                    139
# Asia, North America                        92
# Eurasia, North America, Europe             80
# Asia, North America, Europe                61
# Europe, Oceania                            38
# South America, Europe                      22
# Africa, Europe                             17
# Asia, Eurasia, Europe                      16
# Asia, Africa, Europe                       14
# South America, North America               13
# North America, Oceania                     11
#                                             8
# Africa, North America                       7
# South America, North America, Europe        3
# Eurasia                                     3
# Asia, Africa                                3
# Asia, Oceania                               2
# Asia, Europe, Oceania                       2
# North America, Europe, Oceania              2
# Asia, Africa, Europe, Oceania               1
# Asia, Africa, North America, Europe         1
# Asia, South America, Europe                 1
# Africa, Oceania                             1
# Eurasia, Europe                             1
# South America, Oceania                      1
# dtype: int64

# %%
## Mettre les pays en order alphabétique
df_p.continents = df_p['continents'].apply(lambda x: split_strip_sort(x))
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                      countries          continents  \
# 0    male          Soviet Union, Ukraine         Asia,Europe
# 1  female           India, United States  Asia,North America
# 2    male                 United Kingdom              Europe
# 3    male  Israel, United States, Canada  Asia,North America
# 4    male                 Czechoslovakia              Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             physicist, academic
# 4  physicist, chemist, pharmacist
#
#                                            fields
# 0
# 1
# 2
# 3  nuclear physics, cosmology, general relativity
# 4

# %%
### Regrouper et compter
df_contCode = df_p.groupby('continents').size()
df_contCode.columns=['effectif']
df_contCode = pd.DataFrame(df_contCode.sort_values( ascending = False))
#df_contCode.reset_index(inplace=True)
print(df_contCode.head(10))
# Out:
#                                        0
# continents
# Europe                             13343
# North America                       4248
# Asia                                2055
# Asia,Europe                         1828
# Asia,Eurasia,Europe,North America    416
# Europe,North America                 394
# South America                        389
# Oceania                              288
# Eurasia,North America                192
# Africa                               139

# %%
## Mettre les pays en order alphabétique
df_p.countries = df_p.countries.apply(lambda x: split_strip_sort(x))
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                    countries          continents  \
# 0    male         Soviet Union,Ukraine         Asia,Europe
# 1  female          India,United States  Asia,North America
# 2    male               United Kingdom              Europe
# 3    male  Canada,Israel,United States  Asia,North America
# 4    male               Czechoslovakia              Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             physicist, academic
# 4  physicist, chemist, pharmacist
#
#                                            fields
# 0
# 1
# 2
# 3  nuclear physics, cosmology, general relativity
# 4

# %%
### Regrouper et compter
df_countriesCode = df_p.groupby('countries').size()
df_countriesCode.columns=['effectif']
df_countriesCode = pd.DataFrame(df_countriesCode.sort_values( ascending = False))
#df_contCode.reset_index(inplace=True)
print(df_countriesCode.iloc[:40])
# Out:
#                                                        0
# countries
# United States                                       3773
# Germany                                             2371
# France                                              1480
# Poland                                              1043
# Russia,Soviet Union                                  898
# United Kingdom                                       762
# Italy                                                689
# Japan                                                454
# Hungary                                              438
# Spain                                                432
# Kingdom of the Netherlands                           385
# Soviet Union                                         384
# Sweden                                               344
# Italy,Kingdom of Italy                               343
# Austria                                              342
# Canada                                               325
# Switzerland                                          316
# Russian Empire,Soviet Union                          280
# Czechoslovakia                                       276
# Russia                                               266
# People's Republic of China                           265
# Empire of Japan,Japan                                250
# Estonia                                              244
# Finland                                              228
# Israel                                               208
# United Kingdom of Great Britain and Ireland          206
# Australia                                            201
# Norway                                               201
# Slovenia                                             197
# Kingdom of Italy                                     191
# Russian Empire                                       180
# Soviet Union,Ukraine                                 170
# United Kingdom,United Kingdom of Great Britain ...   170
# Kingdom of Denmark                                   156
# Belgium                                              151
# Argentina                                            146
# Romania                                              140
# Brazil                                               139
# India                                                138
# Czech Republic                                       115

# %%
### How to code the continent of Russians
df_p[df_p.countries.str.contains('Russi')].sort_values(by='birthYear').tail(10)
# Out:
#                                        personUri             personLabel  \
# 18715   http://www.wikidata.org/entity/Q86694290     Andrey A. Kuznetsov
# 1150   http://www.wikidata.org/entity/Q107183155     Sergey D. Mandrykin
# 15491  http://www.wikidata.org/entity/Q107064401           Gennady Losev
# 6864    http://www.wikidata.org/entity/Q71316105            Ivan Volodin
# 17017   http://www.wikidata.org/entity/Q16668276         Vadim Kuznetsov
# 18388    http://www.wikidata.org/entity/Q5917820       Jurij B. Kolesnik
# 19402   http://www.wikidata.org/entity/Q48358871  Vladimir V. Zhivonitko
# 15947   http://www.wikidata.org/entity/Q15453849        Eugene Bogomolny
# 17073  http://www.wikidata.org/entity/Q112033427     Kirill Kliuchinskii
# 13487    http://www.wikidata.org/entity/Q2498733        Elena V. Pitjeva
#
#        birthYear  gender            countries   continents  \
# 18715       1990    male               Russia       Europe
# 1150        1993    male               Russia       Europe
# 15491       1993    male               Russia       Europe
# 6864        1994    male               Russia       Europe
# 17017       2000    male  Russia,Soviet Union  Asia,Europe
# 18388       2000    male  Russia,Soviet Union  Asia,Europe
# 19402       2000    male               Russia       Europe
# 15947       2000    male               Russia       Europe
# 17073       2000    male               Russia       Europe
# 13487       2000  female               Russia       Europe
#
#                                occupations                fields
# 18715                            physicist         hydrodynamics
# 1150                             physicist  magnetohydrodynamics
# 15491                            physicist  magnetohydrodynamics
# 6864   chess player, programmer, physicist         hydrodynamics
# 17017                            physicist
# 18388                physicist, astronomer
# 19402                   physicist, chemist
# 15947                            physicist
# 17073                              student             astronomy
# 13487                           astronomer

# %%
### 
df_p.iloc[ 97:101 , : ]
# Out:
#                                      personUri               personLabel  \
# 97     http://www.wikidata.org/entity/Q2573136  Wilhelm Heinrich Heraeus
# 98     http://www.wikidata.org/entity/Q1730238   Karl Albert Hasselbalch
# 99     http://www.wikidata.org/entity/Q4131361            Andrey Gagarin
# 100  http://www.wikidata.org/entity/Q107844507             Stefania Gori
#
#      birthYear  gender                                          countries  \
# 97        1900    male                                            Germany
# 98        1874    male                                 Kingdom of Denmark
# 99        1856    male  Russian Empire,Russian Soviet Federative Socia...
# 100       1983  female                                              Italy
#
#                 continents                         occupations   fields  \
# 97                  Europe    physicist, entrepreneur, chemist
# 98                  Europe                  physicist, chemist
# 99   Eurasia,North America  pedagogue, mathematician, engineer  physics
# 100                 Europe                           physicist
#
#     contCode
# 97    Europe
# 98    Europe
# 99   Eurasia
# 100   Europe

# %%
# Noter la personne index 116, František Doutlík trouvé grâce à la propriété 'field'
df_p.iloc[ 111:118 :  ]
# Out:
#                                      personUri                personLabel  \
# 111    http://www.wikidata.org/entity/Q4511457  Luise Meyer-Schützmeister
# 112   http://www.wikidata.org/entity/Q57024819             Hannes Pichler
# 113  http://www.wikidata.org/entity/Q126718262                  Zhou Lian
# 114    http://www.wikidata.org/entity/Q7085825            Ole Colbjørnsen
# 115   http://www.wikidata.org/entity/Q59624350            Alberto Carlini
# 116   http://www.wikidata.org/entity/Q95361999          František Doutlík
# 117   http://www.wikidata.org/entity/Q17119374               Eliza Wilbur
#
#      birthYear  gender                   countries     continents  \
# 111       1915  female                     Germany         Europe
# 112       1986    male               Austria,Italy         Europe
# 113       1940    male  People's Republic of China           Asia
# 114       1897    male                      Norway         Europe
# 115       1965    male                       Italy         Europe
# 116       1880    male              Czechoslovakia         Europe
# 117       1851  female               United States  North America
#
#                                       occupations  \
# 111                  physicist, nuclear physicist
# 112                         researcher, physicist
# 113                         researcher, physicist
# 114  physicist, journalist, politician, economist
# 115                                     physicist
# 116                 musician, chronicler, teacher
# 117                          inventor, astronomer
#
#                             fields      contCode
# 111                                       Europe
# 112                                       Europe
# 113                                         Asia
# 114                                       Europe
# 115                                       Europe
# 116  astronomy, educational system        Europe
# 117                                 NorthAmerica

# %%
### Personnes trouvées grâce à leur champ, 'field'
# https://stackoverflow.com/questions/21055068/reversal-of-string-contains-in-python-pandas
dff = df_p[~(df_p.occupations.str.contains("astronomer|physicist"))]
print('Effectif: ', len(dff), '\n')
print(dff.head(2).personUri)
dff.head()
# Out:
# Effectif:  437
#
# 94      http://www.wikidata.org/entity/Q72055
# 99    http://www.wikidata.org/entity/Q4131361
# Name: personUri, dtype: object
#                                      personUri        personLabel  birthYear  \
# 94       http://www.wikidata.org/entity/Q72055   Albrecht Wellmer       1933
# 99     http://www.wikidata.org/entity/Q4131361     Andrey Gagarin       1856
# 116   http://www.wikidata.org/entity/Q95361999  František Doutlík       1880
# 128    http://www.wikidata.org/entity/Q4444381   Vladimir Strunin       1953
# 154  http://www.wikidata.org/entity/Q114191385         Q114191385       1946
#
#     gender                                          countries  \
# 94    male                                            Germany
# 99    male  Russian Empire,Russian Soviet Federative Socia...
# 116   male                                     Czechoslovakia
# 128   male                                             Russia
# 154   male                               Belarus,Soviet Union
#
#                 continents                                   occupations  \
# 94                  Europe  philosopher, university teacher, sociologist
# 99   Eurasia,North America            pedagogue, mathematician, engineer
# 116                 Europe                 musician, chronicler, teacher
# 128                 Europe                                     scientist
# 154            Asia,Europe                 university teacher, scientist
#
#                             fields
# 94            mathematics, physics
# 99                         physics
# 116  astronomy, educational system
# 128                        physics
# 154                optics, physics

# %%
### Problème du contienent d'appartenance des russes,
# commetn coder?
dfr = df_p[df_p.countries.str.contains('Russi|Sovi')]
print(len(dfr))
# Out:
# 2871

# %%
show(dfr,  scrollY="300px",
     scrollCollapse=True, paging=False, layout={"topEnd": None}, 
     showIndex=False, column_filters="header", 
     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     search={"regex": True, "caseInsensitive": True},
     # https://mwouts.github.io/itables/downsampling.html
       maxBytes=0)
# Out:
# <table id="itables_4c8aa514_883b_4959_bc46_96efbded5da0" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead><th>personUri</th><th>personLabel</th><th>birthYear</th><th>gender</th><th>countries</th><th>continents</th><th>occupations</th><th>fields</th></thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.0.1 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_0_1);
#
#     document.querySelectorAll("#itables_4c8aa514_883b_4959_bc46_96efbded5da0:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["http://www.wikidata.org/entity/Q97193482", "Q97193482", 1941, "male", "Soviet Union,Ukraine", "Asia,Europe", "physicist", ""], ["http://www.wikidata.org/entity/Q60167219", "Yuri Golembiovsky", 1937, "male", "Russia", "Europe", "physicist, teacher, engineer", ""], ["http://www.wikidata.org/entity/Q52195429", "Konstantin Iosifovich Gringauz", 1918, "male", "Russia,Soviet Union", "Asia,Europe", "physicist", "astrophysics, plasma physics"], ["http://www.wikidata.org/entity/Q4054460", "Meyrkhan Murbakuly Abdildin", 1938, "male", "Kazakhstan,Soviet Union", "Asia,Europe", "theoretical physicist, physicist", ""], ["http://www.wikidata.org/entity/Q7938602", "Vladimir Rojansky", 1900, "male", "Soviet Union,United States", "Asia,Europe,North America", "physicist, university teacher", ""], ["http://www.wikidata.org/entity/Q4095524", "Pyotr Boyarsky", 1943, "male", "Russia,Soviet Union", "Asia,Europe", "physicist, polar explorer, editing staff, geographer, writer, historian, executive", "research expedition, polar expedition, polar research, history of science, historic preservation"], ["http://www.wikidata.org/entity/Q4275887", "Pyotr Makovetsky", 1922, "male", "Soviet Union", "Asia,Europe", "physicist", "physics"], ["http://www.wikidata.org/entity/Q29363866", "Joseph Poliakoff", 1873, "male", "Russian Empire,United Kingdom,United Kingdom of Great Britain and Ireland", "Eurasia,Europe,North America", "inventor, physicist, engineer", ""], ["http://www.wikidata.org/entity/Q12103107", "Amos Diachenko", 1814, "male", "Russian Empire", "Eurasia,North America", "mathematician, astronomer", "astronomy, theory of differential equations, mathematical analysis"], ["http://www.wikidata.org/entity/Q4143505", "Q4143505", 1928, "male", "Soviet Union,Ukraine", "Asia,Europe", "physicist", "solid-state physics, optics, spectroscopy"], ["http://www.wikidata.org/entity/Q92949648", "Q92949648", 1909, "male", "Russia,Soviet Union", "Asia,Europe", "physicist, university teacher", "mathematics"], ["http://www.wikidata.org/entity/Q60832387", "Dmitry Mishin", 1919, "male", "Russia,Russian State,Soviet Union", "Asia,Eurasia,Europe", "physicist, university teacher", "physics"], ["http://www.wikidata.org/entity/Q4131361", "Andrey Gagarin", 1856, "male", "Russian Empire,Russian Soviet Federative Socialist Republic", "Eurasia,North America", "pedagogue, mathematician, engineer", "physics"], ["http://www.wikidata.org/entity/Q28830708", "Ruslan Kazakov", 1980, "male", "Russia,Soviet Union", "Asia,Europe", "physicist, soldier", ""], ["http://www.wikidata.org/entity/Q12118365", "Q12118365", 1945, "male", "Soviet Union,Ukraine", "Asia,Europe", "theoretical physicist", "physics"], ["http://www.wikidata.org/entity/Q12148701", "Pavlo Romanchuk", 1921, "male", "Soviet Union,Ukraine,Ukrainian Soviet Socialist Republic", "Asia,Europe", "physicist", ""], ["http://www.wikidata.org/entity/Q4444381", "Vladimir Strunin", 1953, "male", "Russia", "Europe", "scientist", "physics"], ["http://www.wikidata.org/entity/Q91573443", "Volodymyr Myloslavskyi", 1928, "male", "Soviet Union,Ukraine", "Asia,Europe", "physicist, university teacher", "nonlinear optics"], ["http://www.wikidata.org/entity/Q4072594", "Anatoly Afanasyev", 1942, "male", "Belarus,Soviet Union", "Asia,Europe", "physicist", "physics"], ["http://www.wikidata.org/entity/Q4442656", "Sergey Stishov", 1937, "male", "Russia,Soviet Union", "Asia,Europe", "physicist", ""], ["http://www.wikidata.org/entity/Q114191385", "Q114191385", 1946, "male", "Belarus,Soviet Union", "Asia,Europe", "university teacher, scientist", "optics, physics"], ["http://www.wikidata.org/entity/Q12076719", "Iryna Adamenko", 1935, "female", "Soviet Union,Ukraine", "Asia,Europe", "physicist", "physics"], ["http://www.wikidata.org/entity/Q21641371", "Vladimir Makarov", 1955, "male", "Russia,Soviet Union", "Asia,Europe", "physicist", "in situ mining, geomechanics, geotechnical engineering"], ["http://www.wikidata.org/entity/Q4198551", "Pyot ...

# %%
dfea = df_p[df_p.continents.str.contains('Euras')]
print(len(dfea))
# Out:
# 708

# %%
show(dfea,  scrollY="300px",
     scrollCollapse=True, paging=False, layout={"topEnd": None}, 
     showIndex=False, column_filters="header", 
     columnDefs=[{"className": "dt-left", "targets": "_all"}],
     search={"regex": True, "caseInsensitive": True},
     # https://mwouts.github.io/itables/downsampling.html
       maxBytes=0)
# Out:
# <table id="itables_54ea7014_fef5_49f3_9cee_e05f993ade02" class="display nowrap" data-quarto-disable-processing="true" style="table-layout:auto;width:auto;margin:auto;caption-side:bottom">
# <thead><th>personUri</th><th>personLabel</th><th>birthYear</th><th>gender</th><th>countries</th><th>continents</th><th>occupations</th><th>fields</th></thead><tbody><tr>
# <td style="vertical-align:middle; text-align:left">
# <div style="float:left; margin-right: 10px;">
# <a href=https://mwouts.github.io/itables/><svg class="main-svg" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"
# width="64" viewBox="0 0 500 400" style="font-family: 'Droid Sans', sans-serif;">
#     <g style="fill:#d9d7fc">
#         <path d="M100,400H500V357H100Z" />
#         <path d="M100,300H400V257H100Z" />
#         <path d="M0,200H400V157H0Z" />
#         <path d="M100,100H500V57H100Z" />
#         <path d="M100,350H500V307H100Z" />
#         <path d="M100,250H400V207H100Z" />
#         <path d="M0,150H400V107H0Z" />
#         <path d="M100,50H500V7H100Z" />
#     </g>
#     <g style="fill:#1a1366;stroke:#1a1366;">
#    <rect x="100" y="7" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="5s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="0" y="107" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="3.5s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="0;0;400"
#       dur="3.5s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="207" width="300" height="43">
#     <animate
#       attributeName="width"
#       values="0;300;0"
#       dur="3s"
#       repeatCount="indefinite" />
#     <animate
#       attributeName="x"
#       values="100;100;400"
#       dur="3s"
#       repeatCount="indefinite" />
#   </rect>
#         <rect x="100" y="307" width="400" height="43">
#     <animate
#       attributeName="width"
#       values="0;400;0"
#       dur="4s"
#       repeatCount="indefinite" />
#       <animate
#       attributeName="x"
#       values="100;100;500"
#       dur="4s"
#       repeatCount="indefinite" />
#   </rect>
#         <g style="fill:transparent;stroke-width:8; stroke-linejoin:round" rx="5">
#             <g transform="translate(45 50) rotate(-45)">
#                 <circle r="33" cx="0" cy="0" />
#                 <rect x="-8" y="32" width="16" height="30" />
#             </g>
#
#             <g transform="translate(450 152)">
#                 <polyline points="-15,-20 -35,-20 -35,40 25,40 25,20" />
#                 <rect x="-15" y="-40" width="60" height="60" />
#             </g>
#
#             <g transform="translate(50 352)">
#                 <polygon points="-35,-5 0,-40 35,-5" />
#                 <polygon points="-35,10 0,45 35,10" />
#             </g>
#
#             <g transform="translate(75 250)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#
#             <g transform="translate(425 250) rotate(180)">
#                 <polyline points="-30,30 -60,0 -30,-30" />
#                 <polyline points="0,30 -30,0 0,-30" />
#             </g>
#         </g>
#     </g>
# </svg>
# </a>
# </div>
# <div>
# Loading ITables v2.0.1 from the <code>init_notebook_mode</code> cell...
# (need <a href=https://mwouts.github.io/itables/troubleshooting.html>help</a>?)</td>
# </div>
# </tr></tbody>
#
# </table>
# <script type="module">
#     const { DataTable, jQuery: $ } = await import(window._datatables_src_for_itables_2_0_1);
#
#     document.querySelectorAll("#itables_54ea7014_fef5_49f3_9cee_e05f993ade02:not(.dataTable)").forEach(table => {
#         // Define the table data
#         const data = [["http://www.wikidata.org/entity/Q29363866", "Joseph Poliakoff", 1873, "male", "Russian Empire,United Kingdom,United Kingdom of Great Britain and Ireland", "Eurasia,Europe,North America", "inventor, physicist, engineer", ""], ["http://www.wikidata.org/entity/Q12103107", "Amos Diachenko", 1814, "male", "Russian Empire", "Eurasia,North America", "mathematician, astronomer", "astronomy, theory of differential equations, mathematical analysis"], ["http://www.wikidata.org/entity/Q60832387", "Dmitry Mishin", 1919, "male", "Russia,Russian State,Soviet Union", "Asia,Eurasia,Europe", "physicist, university teacher", "physics"], ["http://www.wikidata.org/entity/Q4131361", "Andrey Gagarin", 1856, "male", "Russian Empire,Russian Soviet Federative Socialist Republic", "Eurasia,North America", "pedagogue, mathematician, engineer", "physics"], ["http://www.wikidata.org/entity/Q4198551", "Pyotr Vasilyevich Isergin", 1870, "male", "Russian Empire,Soviet Union", "Asia,Eurasia,Europe,North America", "physicist, physician", ""], ["http://www.wikidata.org/entity/Q6465763", "Augustyn Pacewicz", 1847, "male", "Russian Empire,Second Polish Republic", "Eurasia,Europe,North America", "physicist", ""], ["http://www.wikidata.org/entity/Q4163345", "Aleksandr Mints", 1895, "male", "Russian Empire,Russian Socialist Federative Soviet Republic,Soviet Union", "Asia,Eurasia,Europe,North America", "physicist, engineer", "radio electronics"], ["http://www.wikidata.org/entity/Q4528472", "Nikolay Scheglov", 1794, "male", "Russian Empire", "Eurasia,North America", "mineralogist, physicist", ""], ["http://www.wikidata.org/entity/Q471369", "Pyotr Lebedev", 1866, "male", "Russian Empire", "Eurasia,North America", "physicist, university teacher", "physics"], ["http://www.wikidata.org/entity/Q2036824", "Ivan Vsevolodovich Meshcherskiy", 1859, "male", "Russian Empire,Soviet Union", "Asia,Eurasia,Europe,North America", "physicist, mathematician, university teacher", "mechanics, physics, solid-state mechanics"], ["http://www.wikidata.org/entity/Q4255063", "Georgy Latyshev", 1907, "male", "Russian Empire,Soviet Union", "Asia,Eurasia,Europe,North America", "physicist, nuclear physicist", "nuclear physics"], ["http://www.wikidata.org/entity/Q1232515", "Dmitry Blokhintsev", 1908, "male", "Russian Empire,Soviet Union", "Asia,Eurasia,Europe,North America", "physicist, university teacher", "theoretical physics, physics"], ["http://www.wikidata.org/entity/Q3738779", "Grigori Levitski", 1852, "male", "Russian Empire", "Eurasia,North America", "seismologist, physicist, university teacher, astronomer", "astronomy, seismology"], ["http://www.wikidata.org/entity/Q741940", "Boris Vorontsov-Velyaminov", 1904, "male", "Russia,Russian Empire,Soviet Union", "Asia,Eurasia,Europe,North America", "astrophysicist, author, astronomer", "astronomy, astrophysics"], ["http://www.wikidata.org/entity/Q4104504", "Aleksandr Vasilyev", 1868, "male", "Russian Empire,Soviet Union", "Asia,Eurasia,Europe,North America", "physicist, surveyor, geodesist, astronomer", "astronomy, geodesy"], ["http://www.wikidata.org/entity/Q4062295", "Mekhti Aliyev", 1907, "male", "Russian Empire,Soviet Union", "Asia,Eurasia,Europe,North America", "physicist", ""], ["http://www.wikidata.org/entity/Q4405658", "Esther Salaman", 1900, "female", "Russian Empire,United Kingdom", "Eurasia,Europe,North America", "physicist, writer", ""], ["http://www.wikidata.org/entity/Q4234368", "Q4234368", 1837, "male", "Russian Empire", "Eurasia,North America", "astronomer", "astronomy"], ["http://www.wikidata.org/entity/Q2087955", "Vasily Engelhardt", 1828, "male", "Russian Empire", "Eurasia,North America", "astronomer", "astronomy"], ["http://www.wikidata.org/entity/Q706120", "Platon Poretsky", 1846, "male", "Russian Empire", "Eurasia,North America", "mathematician, university teacher, astronomer", "astronomy, mathematical logic"], ["http://www.wikidata.org/entity/Q1226083", "Matvei Petrovich Bronstein", 1906, "male", "Russ ...

# %%
### Créer une fonction de codage
def codeContinents(continents, countries):
    
    ## Issue with Russia, Russian Empire, Wikidata not consistent    
    if 'ussi' in countries or 'oviet' in countries:
        output = 'Eurasia'
    elif 'Eurasia' in continents:
        output = 'Eurasia'
    elif 'Asia,Europe' in continents:
        output = 'Eurasia'
    elif 'Africa' in continents:
        output = 'Africa'
    elif 'Oceania' in continents:
        output = 'Oceania'
    elif 'Asia' in continents:
        output = 'Asia'
    elif 'Europe' in continents:
        output = 'Europe'
    elif 'North America' in continents:
        output = 'NorthAmerica'   
    elif 'South America' in continents:
        output = 'SouthAmerica' 
    else:
        output = 'Missing'                 
    return output

# %%
### On ajoute une nouvelle colonne 'contCode' et y on met pour chaque ligne le résultat de la fonction
df_p['contCode'] = df_p.apply(lambda x: codeContinents(x['continents'], x['countries']), axis=1)
df_p.head(3)
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
#
#    gender             countries          continents               occupations  \
# 0    male  Soviet Union,Ukraine         Asia,Europe                 physicist
# 1  female   India,United States  Asia,North America   physicist, biophysicist
# 2    male        United Kingdom              Europe  physicist, mathematician
#
#   fields contCode
# 0         Eurasia
# 1            Asia
# 2          Europe

# %%
### Regrouper et compter
df_contCode = df_p.groupby('contCode').size()
df_contCode = pd.DataFrame(df_contCode)
#df_contCode.reset_index(inplace=True)
df_contCode.columns=['effectif']
print(df_contCode.sort_values('effectif',ascending = False))
# Out:
#               effectif
# contCode
# Europe           13324
# NorthAmerica      4261
# Eurasia           3063
# Asia              2138
# SouthAmerica       389
# Oceania            342
# Africa             167
# Missing              8

# %%
 
### Regrouper et compter les personnes issues de Russie
# le codage 
df_contCode = df_p[df_p.countries.str.contains('ussi|oviet')].groupby('contCode').size()
df_contCode = pd.DataFrame(df_contCode.sort_values(ascending = True))
#df_contCode.reset_index(inplace=True)
df_contCode.columns=['effectif']
print(df_contCode)
# Out:
#           effectif
# contCode
# Eurasia       3010

# %%
df_p[(df_p.countries.str.contains('ussi|oviet')) & (df_p.contCode.str.contains('Europe'))].head(10)
# Out:
# Empty DataFrame
# Columns: [personUri, personLabel, birthYear, gender, countries, continents, occupations, fields, contCode]
# Index: []

# %% [markdown]
# ### Continents: codage par période de vingt-cinq ans

# %%
### Créer une liste d'années pour séparer en périodes de 25 ans
# noter que la dernière année sera exclue, 
# elle donc doit être supérieure à la valeur maximale 
l_25 = list(range(1751, 2025, 25))
print(l_25[:5],l_25[-5:], len(l_25)-1)
# Out:
# [1751, 1776, 1801, 1826, 1851] [1901, 1926, 1951, 1976, 2001] 10

# %%
### Transformer les années de naissance en entiers
df_p.birthYear = df_p.birthYear.apply(lambda x : int(x))

# %%
### fonction pd.cut : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.cut.html
# On ajoute une nouvelle colonne qui contient la période sur la base de la liste précédente
# et de la valeur de l'année

df_p['per_25'] = pd.cut(df_p['birthYear'], l_25, right=False)

### Transformer le code ajouté pour qu'il soit plus lisible
# noter qu'on a arrondi les valeurs
df_p['per_25'] = df_p['per_25'].apply(lambda x : str(int(x.left))+'-'+ str(int(x.right)-1))

# Inspection
df_p.head(3)
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
#
#    gender             countries          continents               occupations  \
# 0    male  Soviet Union,Ukraine         Asia,Europe                 physicist
# 1  female   India,United States  Asia,North America   physicist, biophysicist
# 2    male        United Kingdom              Europe  physicist, mathematician
#
#   fields contCode     per_25
# 0         Eurasia  1926-1950
# 1            Asia  1951-1975
# 2          Europe  1901-1925

# %%
### distribution des naissances par périodes de 25 ans
naissances_per = df_p.groupby(by='per_25', observed=True).size()
print(naissances_per)
# Out:
# per_25
# 1751-1775     254
# 1776-1800     328
# 1801-1825     534
# 1826-1850     812
# 1851-1875    1312
# 1876-1900    1918
# 1901-1925    4216
# 1926-1950    8136
# 1951-1975    4960
# 1976-2000    1222
# dtype: int64

# %% [markdown]
# ## Analyse bivariée: périodes, continents

# %%
### Tableau de contingence
X = "contCode"
Y = "per_25"  # "0"

ddf = df_p[[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
ddf = ddf[['Europe', 'Eurasia',  'NorthAmerica', 'Asia', 'Africa', 'Oceania', 'SouthAmerica', 'Total']]
ddf
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica  \
# per_25
# 1751-1775     212       26             4     8       0        1             1
# 1776-1800     257       47            17     3       1        2             1
# 1801-1825     390       83            47     7       2        2             3
# 1826-1850     574      117            97     6       2       10             5
# 1851-1875     873      169           201    24       6       27            12
# 1876-1900    1231      234           328    84       9       20            12
# 1901-1925    1957      689          1022   385      21       82            59
# 1926-1950    4072     1266          1567   916      46      118           148
# 1951-1975    2980      371           784   596      49       68           111
# 1976-2000     778       61           194   109      31       12            37
# Total       13324     3063          4261  2138     167      342           389
#
# contCode   Total
# per_25
# 1751-1775    254
# 1776-1800    328
# 1801-1825    534
# 1826-1850    812
# 1851-1875   1312
# 1876-1900   1918
# 1901-1925   4216
# 1926-1950   8136
# 1951-1975   4960
# 1976-2000   1222
# Total      23692

# %%
### Adapter à l'ordre des colonnes
col_palette_1 = [
    "#DCDCDC",  # Gainsboro : Europe
    "#E3D4AD",  # Desert Sand : Eurasia
    "#cd5c5c",  # Indian Red : NorthAmerica
    "#F4A261",  # Light Coral : Asia
    "#A3C1DA",  # Light Blue : Africa
    "#B2E0B2",  # Light Green : Oceania
    "#F6E58D",  # Light Yellow : SouthAmerica
    
]

# %%
### Représenter l'évolution de la distribution dans le temps par continent
#  Documentation
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html

data = ddf.iloc[:-1,:-1]

ax = data.plot.bar(stacked=True, rot=70, fontsize=9, figsize=(10,8), 
                     color=col_palette_1)
plt.title('Distribution des naissances par génération et continent')

## https://stackoverflow.com/questions/71320380/add-only-the-total-values-on-top-of-stacked-bars
ax.bar_label(ax.containers[-1])

plt.show()

# %% [markdown]
# ### Créer les fonctions

# %%
### ct_m : contingency table without totals in margins
def bivariee_stats(ct_wm):
    
    
    n = ct_wm.sum().sum()

    ### Valeurs produites par la fonction de la librairie 'stats'
    statistic, p, dof, expected = stats.chi2_contingency(ct_wm)

    print('Chi2 :', statistic.round(2), ', dof :',dof)
    print('p-value :', p)

    

    print('phi2 = inertie (variance totale) :', statistic/n)


    ### Tableau à l'indépendance
    dfe = round(pd.DataFrame(expected),4)

    ### Coéfficient de Cramer
    # https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.contingency.association.html

    vc = stats.contingency.association(ct_wm, method='cramer')
    print('Cramer: ', vc)

    return None

# %%
ct_wm = ddf.iloc[3:-2,:-1].copy(deep=True)
ct_wm
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850     574      117            97     6       2       10             5
# 1851-1875     873      169           201    24       6       27            12
# 1876-1900    1231      234           328    84       9       20            12
# 1901-1925    1957      689          1022   385      21       82            59
# 1926-1950    4072     1266          1567   916      46      118           148
# 1951-1975    2980      371           784   596      49       68           111

# %%
bivariee_stats(ct_wm)
# Out:
# Chi2 : 851.28 , dof : 30
# p-value : 1.0643685508053283e-159
# phi2 = inertie (variance totale) : 0.03987644198468521
# Cramer:  0.08930447019571328

# %%
### ct_m : contingency tables with totals in margins
def plot_chi2_residuals(ct_wm, figsize=(9,3)):
    
    D = ct_wm

    
    ### Valeurs produites par la fonction de la librairie 'stats'
    statistic, p, dof, expected = stats.chi2_contingency(D)

    ### Situation à l'indépendance
    indep = pd.DataFrame(expected)
    indep.columns = D.columns
    indep.index = D.index

    ### Résidus pondérés (avec le signe)
    ### Doc. :
    #   Rakotomalala, p.240
    residus_ponderes = (round((D-indep)/np.sqrt(indep),2))
    ### Résidus pondérés
    tableau = residus_ponderes
   

    fig, ax = plt.subplots(figsize=figsize)         
    # Sample figsize in inches
    g = sns.heatmap(tableau, annot=tableau, cmap="coolwarm", linewidths=.5, ax=ax)
    xlabels = tableau.columns
    px = g.set_xticklabels(xlabels, rotation=60, size=8, 
                           ha='right', rotation_mode='anchor')
    ylabels = tableau.index
    py = g.set_yticklabels(ylabels, rotation=20, size=8)
    
    plt.show()

# %%
pp = plot_chi2_residuals(ct_wm, figsize=(12, 4))

# %% [markdown]
# ### Analyse factorielle des correspondances (AFC)

# %%
ct_wm
# Out:
# contCode   Europe  Eurasia  NorthAmerica  Asia  Africa  Oceania  SouthAmerica
# per_25
# 1826-1850     574      117            97     6       2       10             5
# 1851-1875     873      169           201    24       6       27            12
# 1876-1900    1231      234           328    84       9       20            12
# 1901-1925    1957      689          1022   385      21       82            59
# 1926-1950    4072     1266          1567   916      46      118           148
# 1951-1975    2980      371           784   596      49       68           111

# %%
afc = CA(row_labels=ct_wm.index,col_labels=ct_wm.columns)
afc.fit(ct_wm.values)
# Out:
# CA(col_labels=Index(['Europe', 'Eurasia', 'NorthAmerica', 'Asia', 'Africa', 'Oceania',
#        'SouthAmerica'],
#       dtype='object', name='contCode'),
#    row_labels=Index(['1826-1850', '1851-1875', '1876-1900', '1901-1925', '1926-1950',
#        '1951-1975'],
#       dtype='object', name='per_25'))

# %%
def print_eigenvalue(afc):

    eig = pd.DataFrame(afc.eig_)

    r1 = round(eig.iloc[0], 3)
    r2 = round(eig.iloc[2], 2)
    s=list(range(1,len(r1)+1))
    r1.index=s
    r2.index=s

    # https://www.statology.org/pandas-subplots/
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12,3))

    ax1 = r1.plot(kind='bar', ax=axes[0], title='Eigenvalue des axes')
    ax2 = r2.plot(kind='bar', ax=axes[1], title="Frequence cumulative de l'eigenvalue ")


    ax1.bar_label(ax1.containers[0])
    ax2.bar_label(ax2.containers[0])


    # Met les valeurs xticks en vertical
    fig.autofmt_xdate(rotation=0)
    plt.show()

# %%
print_eigenvalue(afc)

# %%
def contributions_colonnes(afc):
    
    # Informations sur les contributions des colonnes
    df = afc.col_topandas()[['col_contrib_dim1',
                            'col_contrib_dim2',
                            'col_contrib_dim3']]

    r1 = df.iloc[:,0]
    r2 = df.iloc[:,1]
    r3 = df.iloc[:,2]

    fig, axes = plt.subplots(nrows=2, ncols=3, figsize=(12,4))

    r1.sort_values().plot(kind='barh', ax=axes[0,0], title='Dim.1')
    r2.sort_values().plot(kind='barh', ax=axes[0,1], title='Dim.2')
    r3.sort_values().plot(kind='barh', ax=axes[0,2], title='Dim.3')

    ### Rows
    df = afc.row_topandas()[['row_contrib_dim1',
                            'row_contrib_dim2',
                            'row_contrib_dim3']]
    r1 = df.iloc[:,0]
    r2 = df.iloc[:,1]
    r3 = df.iloc[:,2]

    r1.sort_values().plot(kind='barh', ax=axes[1,0], title='Dim.1')
    r2.sort_values().plot(kind='barh', ax=axes[1,1], title='Dim.2')
    r3.sort_values().plot(kind='barh', ax=axes[1,2], title='Dim.3')

    plt.tight_layout()
    plt.show()

# %%
contributions_colonnes(afc)

# %%
# Représentation simultanée, avec amplification
afc.mapping(num_x_axis=1,num_y_axis=2,figsize=(7,7))

# %%
# Représentation simultanée, avec amplification
afc.mapping(num_x_axis=2,num_y_axis=3,figsize=(7,7))

# %%
pp = plot_chi2_residuals(ct_wm, figsize=(10, 4))

# %% [markdown]
# ## Continent et genre

# %%
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                    countries          continents  \
# 0    male         Soviet Union,Ukraine         Asia,Europe
# 1  female          India,United States  Asia,North America
# 2    male               United Kingdom              Europe
# 3    male  Canada,Israel,United States  Asia,North America
# 4    male               Czechoslovakia              Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             physicist, academic
# 4  physicist, chemist, pharmacist
#
#                                            fields contCode     per_25
# 0                                                  Eurasia  1926-1950
# 1                                                     Asia  1951-1975
# 2                                                   Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity     Asia  1901-1925
# 4                                                   Europe  1926-1950

# %%
### Tableau de contingence
X = "contCode"
Y = "gender"  # "0"

ddgc = df_p[(df_p.contCode!='Missing') & (df_p.gender.isin(['female', 'male']))]\
            [[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
ddgc
# Out:
# contCode  Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  SouthAmerica  \
# gender
# female        41   159      150    1166           482       37            87
# male         126  1976     2913   12155          3773      302           302
# Total        167  2135     3063   13321          4255      339           389
#
# contCode  Total
# gender
# female     2122
# male      21547
# Total     23669

# %% [markdown]
# ### Genre et continent par époque

# %%
df_p['genre_cont'] = df_p.apply(lambda x: x.contCode + '_' + x.gender, axis=1)
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                    countries          continents  \
# 0    male         Soviet Union,Ukraine         Asia,Europe
# 1  female          India,United States  Asia,North America
# 2    male               United Kingdom              Europe
# 3    male  Canada,Israel,United States  Asia,North America
# 4    male               Czechoslovakia              Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             physicist, academic
# 4  physicist, chemist, pharmacist
#
#                                            fields contCode     per_25  \
# 0                                                  Eurasia  1926-1950
# 1                                                     Asia  1951-1975
# 2                                                   Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity     Asia  1901-1925
# 4                                                   Europe  1926-1950
#
#      genre_cont
# 0  Eurasia_male
# 1   Asia_female
# 2   Europe_male
# 3     Asia_male
# 4   Europe_male

# %%
### Tableau de contingence
X = "genre_cont"
Y = "per_25"  # "0"

ddgcp = df_p[(df_p.contCode!='Missing') & (df_p.gender.isin(['female', 'male']))]\
                [[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
ddgcp
# Out:
# genre_cont  Africa_female  Africa_male  Asia_female  Asia_male  \
# per_25
# 1751-1775               0            0            1          7
# 1776-1800               0            1            0          3
# 1801-1825               0            2            0          7
# 1826-1850               0            2            0          6
# 1851-1875               0            6            0         24
# 1876-1900               0            9            0         84
# 1901-1925               3           18           27        357
# 1926-1950               5           41           42        873
# 1951-1975              15           34           62        534
# 1976-2000              18           13           27         81
# Total                  41          126          159       1976
#
# genre_cont  Eurasia_female  Eurasia_male  Europe_female  Europe_male  \
# per_25
# 1751-1775                0            26              4          208
# 1776-1800                0            47              6          251
# 1801-1825                0            83              3          387
# 1826-1850                1           116             10          564
# 1851-1875                5           164             30          843
# 1876-1900               22           212             81         1150
# 1901-1925               38           651            143         1814
# 1926-1950               49          1217            280         3791
# 1951-1975               23           348            412         2567
# 1976-2000               12            49            197          580
# Total                  150          2913           1166        12155
#
# genre_cont  NorthAmerica_female  NorthAmerica_male  Oceania_female  \
# per_25
# 1751-1775                     0                  4               0
# 1776-1800                     0                 17               0
# 1801-1825                     4                 43               0
# 1826-1850                     7                 90               0
# 1851-1875                    23                178               2
# 1876-1900                    45                283               1
# 1901-1925                    72                950               6
# 1926-1950                   119               1448               8
# 1951-1975                   150                632              15
# 1976-2000                    62                128               5
# Total                       482               3773              37
#
# genre_cont  Oceania_male  SouthAmerica_female  SouthAmerica_male  Total
# per_25
# 1751-1775              1                    0                  1    252
# 1776-1800              2                    0                  1    328
# 1801-1825              2                    0                  3    534
# 1826-1850             10                    0                  5    811
# 1851-1875             25                    0                 12   1312
# 1876-1900             19                    0                 12   1918
# 1901-1925             76                   13                 46   4214
# 1926-1950            109                   26                122   8130
# 1951-1975             51                   36                 75   4954
# 1976-2000              7                   12                 25   1216
# Total                302                   87                302  23669

# %%
### Limiter à la période significative, 20 siècle
D = ddgcp.iloc[6:-1,:-1].copy(deep=True)
D
# Out:
# genre_cont  Africa_female  Africa_male  Asia_female  Asia_male  \
# per_25
# 1901-1925               3           18           27        357
# 1926-1950               5           41           42        873
# 1951-1975              15           34           62        534
# 1976-2000              18           13           27         81
#
# genre_cont  Eurasia_female  Eurasia_male  Europe_female  Europe_male  \
# per_25
# 1901-1925               38           651            143         1814
# 1926-1950               49          1217            280         3791
# 1951-1975               23           348            412         2567
# 1976-2000               12            49            197          580
#
# genre_cont  NorthAmerica_female  NorthAmerica_male  Oceania_female  \
# per_25
# 1901-1925                    72                950               6
# 1926-1950                   119               1448               8
# 1951-1975                   150                632              15
# 1976-2000                    62                128               5
#
# genre_cont  Oceania_male  SouthAmerica_female  SouthAmerica_male
# per_25
# 1901-1925             76                   13                 46
# 1926-1950            109                   26                122
# 1951-1975             51                   36                 75
# 1976-2000              7                   12                 25

# %%
### Exclure l'Afrique
D = ddgcp.iloc[6:-1,2:-1].copy(deep=True)
D
# Out:
# genre_cont  Asia_female  Asia_male  Eurasia_female  Eurasia_male  \
# per_25
# 1901-1925            27        357              38           651
# 1926-1950            42        873              49          1217
# 1951-1975            62        534              23           348
# 1976-2000            27         81              12            49
#
# genre_cont  Europe_female  Europe_male  NorthAmerica_female  \
# per_25
# 1901-1925             143         1814                   72
# 1926-1950             280         3791                  119
# 1951-1975             412         2567                  150
# 1976-2000             197          580                   62
#
# genre_cont  NorthAmerica_male  Oceania_female  Oceania_male  \
# per_25
# 1901-1925                 950               6            76
# 1926-1950                1448               8           109
# 1951-1975                 632              15            51
# 1976-2000                 128               5             7
#
# genre_cont  SouthAmerica_female  SouthAmerica_male
# per_25
# 1901-1925                    13                 46
# 1926-1950                    26                122
# 1951-1975                    36                 75
# 1976-2000                    12                 25

# %%
## Appliquer la fonction
bivariee_stats(D)
# Out:
# Chi2 : 1114.3 , dof : 33
# p-value : 7.795328317610967e-213
# phi2 = inertie (variance totale) : 0.06066875194729768
# Cramer:  0.1422073040169382

# %% [markdown]
# ### AFC

# %%
afc = CA(row_labels=D.index,col_labels=D.columns)
afc.fit(D.values)
# Out:
# CA(col_labels=Index(['Asia_female', 'Asia_male', 'Eurasia_female', 'Eurasia_male',
#        'Europe_female', 'Europe_male', 'NorthAmerica_female',
#        'NorthAmerica_male', 'Oceania_female', 'Oceania_male',
#        'SouthAmerica_female', 'SouthAmerica_male'],
#       dtype='object', name='genre_cont'),
#    row_labels=Index(['1901-1925', '1926-1950', '1951-1975', '1976-2000'], dtype='object', name='per_25'))

# %%
print_eigenvalue(afc)

# %%
contributions_colonnes(afc)

# %%
# Représentation simultanée, avec amplification
afc.mapping(num_x_axis=1,num_y_axis=2,figsize=(10,10))

# %%
# Représentation simultanée, avec amplification
afc.mapping(num_x_axis=2,num_y_axis=3,figsize=(10,10))

# %%
pp = plot_chi2_residuals(D, figsize=(10, 4))

# %% [markdown]
# ## Continent et discipline

# %%
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                    countries          continents  \
# 0    male         Soviet Union,Ukraine         Asia,Europe
# 1  female          India,United States  Asia,North America
# 2    male               United Kingdom              Europe
# 3    male  Canada,Israel,United States  Asia,North America
# 4    male               Czechoslovakia              Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             physicist, academic
# 4  physicist, chemist, pharmacist
#
#                                            fields contCode     per_25  \
# 0                                                  Eurasia  1926-1950
# 1                                                     Asia  1951-1975
# 2                                                   Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity     Asia  1901-1925
# 4                                                   Europe  1926-1950
#
#      genre_cont
# 0  Eurasia_male
# 1   Asia_female
# 2   Europe_male
# 3     Asia_male
# 4   Europe_male

# %%
def code_discipline(col1, col2):
    if  'astronomer' in col1\
        or 'astronomy' in col2:
        output = 'astronomy'
    elif 'physicist' in col1\
        or 'physics' in col2:
        output = 'physics'
    else:
        output = 'other'
    return output

# %%
df_p['code_discipline'] = df_p.apply(lambda x: code_discipline(x.occupations, x.fields), axis=1)
df_p.head()
# Out:
#                                   personUri          personLabel  birthYear  \
# 0  http://www.wikidata.org/entity/Q97193482            Q97193482       1941
# 1   http://www.wikidata.org/entity/Q4511380           Anita Goel       1973
# 2   http://www.wikidata.org/entity/Q4706857  Alan Herries Wilson       1906
# 3  http://www.wikidata.org/entity/Q61552351     Gerald E. Tauber       1922
# 4  http://www.wikidata.org/entity/Q95157297     Kristian Svoboda       1931
#
#    gender                    countries          continents  \
# 0    male         Soviet Union,Ukraine         Asia,Europe
# 1  female          India,United States  Asia,North America
# 2    male               United Kingdom              Europe
# 3    male  Canada,Israel,United States  Asia,North America
# 4    male               Czechoslovakia              Europe
#
#                       occupations  \
# 0                       physicist
# 1         physicist, biophysicist
# 2        physicist, mathematician
# 3             physicist, academic
# 4  physicist, chemist, pharmacist
#
#                                            fields contCode     per_25  \
# 0                                                  Eurasia  1926-1950
# 1                                                     Asia  1951-1975
# 2                                                   Europe  1901-1925
# 3  nuclear physics, cosmology, general relativity     Asia  1901-1925
# 4                                                   Europe  1926-1950
#
#      genre_cont code_discipline
# 0  Eurasia_male         physics
# 1   Asia_female         physics
# 2   Europe_male         physics
# 3     Asia_male         physics
# 4   Europe_male         physics

# %%
df_p.groupby('code_discipline').size()
# Out:
# code_discipline
# astronomy     5814
# physics      17878
# dtype: int64

# %%
### Tableau de contingence
X = "contCode"
Y = "code_discipline"  # "0"

dddc = df_p[(df_p.contCode!='Missing') & (df_p.gender.isin(['female', 'male']))]\
        [[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
dddc
# Out:
# contCode         Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  \
# code_discipline
# astronomy            52   495      554    3093          1369      117
# physics             115  1640     2509   10228          2886      222
# Total               167  2135     3063   13321          4255      339
#
# contCode         SouthAmerica  Total
# code_discipline
# astronomy                 121   5801
# physics                   268  17868
# Total                     389  23669

# %%
### Profils des lignes
# axis=0 pour les colonnes

dddc_pl = dddc.apply(lambda x: (x/sum(x)*100*2).round(1), axis=1) 
dddc_pl
# Out:
# contCode         Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  \
# code_discipline
# astronomy           0.9   8.5      9.6    53.3          23.6      2.0
# physics             0.6   9.2     14.0    57.2          16.2      1.2
# Total               0.7   9.0     12.9    56.3          18.0      1.4
#
# contCode         SouthAmerica  Total
# code_discipline
# astronomy                 2.1  100.0
# physics                   1.5  100.0
# Total                     1.6  100.0

# %%
### Adapter à l'ordre des colonnes
col_palette_2 = [
    "#A3C1DA",  # Light Blue : Africa
    "#F4A261",  # Light Coral : Asia
    "#E3D4AD",  # Desert Sand : Eurasia
    "#DCDCDC",  # Gainsboro : Europe
    "#cd5c5c",  # Indian Red : NorthAmerica
    "#B2E0B2",  # Light Green : Oceania
    "#F6E58D",  # Light Yellow : SouthAmerica
    
]

# %%
### https://www.shanelynn.ie/bar-plots-in-python-using-pandas-dataframes/

ax = dddc_pl.iloc[:, :-1].sort_index(ascending=False).plot(kind="barh",
                    stacked=True, figsize=(20,6), title='Proportion des produits vendus par région',
                    color=col_palette_2
                    )

### https://stackoverflow.com/questions/25447700/annotate-bars-with-values-on-pandas-bar-plots

for p in ax.patches:
    b = p.get_bbox()
    y_value=b.y1-b.y0
    ax.annotate(format(p.get_width(), '.1f'), 
                   (p.get_x() + p.get_width()/2, p.get_y() + p.get_height()), 
                   ha = 'center', va = 'center', 
                   size=10,
                   # style = 'italic',
                   weight='bold',
                   color = 'white',
                   xytext = (0, -12), 
                   textcoords = 'offset points')

ax.legend(bbox_to_anchor=(0.9, 1))

plt.show()

# %%
### Production du tableau à analyser
## Noter que pour que l'analyse soit significative en 
# termes de Chi-2 il faudrait partir de la ligne quatre
# Aussi, la dernière ligne est probablement incomplète
# en termes de génération
D = dddc.iloc[:-1,:-1].copy(deep=True)
D
# Out:
# contCode         Africa  Asia  Eurasia  Europe  NorthAmerica  Oceania  \
# code_discipline
# astronomy            52   495      554    3093          1369      117
# physics             115  1640     2509   10228          2886      222
#
# contCode         SouthAmerica
# code_discipline
# astronomy                 121
# physics                   268

# %%
## Appliquer la fonction
bivariee_stats(D)
# Out:
# Chi2 : 248.85 , dof : 6
# p-value : 7.2276212002404e-51
# phi2 = inertie (variance totale) : 0.010513688803711146
# Cramer:  0.10253628042654535

# %% [markdown]
# ## Discipline et continent par époque

# %%
df_p.head(2)
# Out:
#                                   personUri personLabel  birthYear  gender  \
# 0  http://www.wikidata.org/entity/Q97193482   Q97193482       1941    male
# 1   http://www.wikidata.org/entity/Q4511380  Anita Goel       1973  female
#
#               countries          continents              occupations fields  \
# 0  Soviet Union,Ukraine         Asia,Europe                physicist
# 1   India,United States  Asia,North America  physicist, biophysicist
#
#   contCode     per_25    genre_cont code_discipline
# 0  Eurasia  1926-1950  Eurasia_male         physics
# 1     Asia  1951-1975   Asia_female         physics

# %%
df_p['disc_cont'] = df_p.apply(lambda x: x.contCode + '_' + x.code_discipline, axis=1)
df_p.head(2)
# Out:
#                                   personUri personLabel  birthYear  gender  \
# 0  http://www.wikidata.org/entity/Q97193482   Q97193482       1941    male
# 1   http://www.wikidata.org/entity/Q4511380  Anita Goel       1973  female
#
#               countries          continents              occupations fields  \
# 0  Soviet Union,Ukraine         Asia,Europe                physicist
# 1   India,United States  Asia,North America  physicist, biophysicist
#
#   contCode     per_25    genre_cont code_discipline        disc_cont
# 0  Eurasia  1926-1950  Eurasia_male         physics  Eurasia_physics
# 1     Asia  1951-1975   Asia_female         physics     Asia_physics

# %%
### Tableau de contingence
X = "disc_cont"
Y = "per_25"  # "0"

dddcp = df_p[(df_p.contCode!='Missing') & (df_p.gender.isin(['female', 'male']))]\
            [[X,Y]].pivot_table(index=Y,columns=X,observed=True, aggfunc=len,margins=True,margins_name="Total").fillna(0).astype(int)
dddcp
# Out:
# disc_cont  Africa_astronomy  Africa_physics  Asia_astronomy  Asia_physics  \
# per_25
# 1751-1775                 0               0               8             0
# 1776-1800                 1               0               3             0
# 1801-1825                 2               0               6             1
# 1826-1850                 2               0               4             2
# 1851-1875                 5               1               9            15
# 1876-1900                 6               3              24            60
# 1901-1925                 8              13              63           321
# 1926-1950                12              34             189           726
# 1951-1975                10              39             148           448
# 1976-2000                 6              25              41            67
# Total                    52             115             495          1640
#
# disc_cont  Eurasia_astronomy  Eurasia_physics  Europe_astronomy  \
# per_25
# 1751-1775                 12               14               114
# 1776-1800                 34               13               122
# 1801-1825                 35               48               175
# 1826-1850                 49               68               238
# 1851-1875                 61              108               330
# 1876-1900                 76              158               323
# 1901-1925                123              566               392
# 1926-1950                128             1138               606
# 1951-1975                 26              345               609
# 1976-2000                 10               51               184
# Total                    554             2509              3093
#
# disc_cont  Europe_physics  NorthAmerica_astronomy  NorthAmerica_physics  \
# per_25
# 1751-1775              98                       2                     2
# 1776-1800             135                      10                     7
# 1801-1825             215                      33                    14
# 1826-1850             336                      69                    28
# 1851-1875             543                     109                    92
# 1876-1900             908                     113                   215
# 1901-1925            1565                     194                   828
# 1926-1950            3465                     408                  1159
# 1951-1975            2370                     346                   436
# 1976-2000             593                      85                   105
# Total               10228                    1369                  2886
#
# disc_cont  Oceania_astronomy  Oceania_physics  SouthAmerica_astronomy  \
# per_25
# 1751-1775                  1                0                       1
# 1776-1800                  2                0                       0
# 1801-1825                  2                0                       3
# 1826-1850                  9                1                       3
# 1851-1875                 17               10                       5
# 1876-1900                  6               14                       7
# 1901-1925                 24               58                      20
# 1926-1950                 23               94                      28
# 1951-1975                 24               42                      32
# 1976-2000                  9                3                      22
# Total                    117              222                     121
#
# disc_cont  SouthAmerica_physics  Total
# per_25
# 1751-1775                     0    252
# 1776-1800                     1    328
# 1801-1825                     0    534
# 1826-1850                     2    811
# 1851-1875                     7   1312
# 1876-1900                     5   1918
# 1901-1925                    39   4214
# 1926-1950                   120   8130
# 1951-1975                    79   4954
# 1976-2000                    15   1216
# Total                       268  23669

# %%
### Limiter à la période significative, 20 siècle
D = dddcp.iloc[5:-1,:-1].copy(deep=True)
D
# Out:
# disc_cont  Africa_astronomy  Africa_physics  Asia_astronomy  Asia_physics  \
# per_25
# 1876-1900                 6               3              24            60
# 1901-1925                 8              13              63           321
# 1926-1950                12              34             189           726
# 1951-1975                10              39             148           448
# 1976-2000                 6              25              41            67
#
# disc_cont  Eurasia_astronomy  Eurasia_physics  Europe_astronomy  \
# per_25
# 1876-1900                 76              158               323
# 1901-1925                123              566               392
# 1926-1950                128             1138               606
# 1951-1975                 26              345               609
# 1976-2000                 10               51               184
#
# disc_cont  Europe_physics  NorthAmerica_astronomy  NorthAmerica_physics  \
# per_25
# 1876-1900             908                     113                   215
# 1901-1925            1565                     194                   828
# 1926-1950            3465                     408                  1159
# 1951-1975            2370                     346                   436
# 1976-2000             593                      85                   105
#
# disc_cont  Oceania_astronomy  Oceania_physics  SouthAmerica_astronomy  \
# per_25
# 1876-1900                  6               14                       7
# 1901-1925                 24               58                      20
# 1926-1950                 23               94                      28
# 1951-1975                 24               42                      32
# 1976-2000                  9                3                      22
#
# disc_cont  SouthAmerica_physics
# per_25
# 1876-1900                     5
# 1901-1925                    39
# 1926-1950                   120
# 1951-1975                    79
# 1976-2000                    15

# %%
## Appliquer la fonction
bivariee_stats(D)
# Out:
# Chi2 : 1188.67 , dof : 52
# p-value : 1.1530302116737008e-214
# phi2 = inertie (variance totale) : 0.05817700067235122
# Cramer:  0.12059954464295379

# %% [markdown]
# ### AFC

# %%
afc = CA(row_labels=D.index,col_labels=D.columns)
afc.fit(D.values)
# Out:
# CA(col_labels=Index(['Africa_astronomy', 'Africa_physics', 'Asia_astronomy', 'Asia_physics',
#        'Eurasia_astronomy', 'Eurasia_physics', 'Europe_astronomy',
#        'Europe_physics', 'NorthAmerica_astronomy', 'NorthAmerica_physics',
#        'Oceania_astronomy', 'Oceania_physics', 'SouthAmerica_astronomy',
#        'SouthAmerica_physics'],
#       dtype='object', name='disc_cont'),
#    row_labels=Index(['1876-1900', '1901-1925', '1926-1950', '1951-1975', '1976-2000'], dtype='object', name='per_25'))

# %%
print_eigenvalue(afc)

# %%
contributions_colonnes(afc)

# %%
# Représentation simultanée, avec amplification
afc.mapping(num_x_axis=1,num_y_axis=2,figsize=(9,9))

# %%
# Représentation simultanée, avec amplification
afc.mapping(num_x_axis=2,num_y_axis=3,figsize=(14,7))

# %%
pp = plot_chi2_residuals(D, figsize=(10, 4))
